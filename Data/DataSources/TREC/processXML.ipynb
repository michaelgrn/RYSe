# %%
import xmltodict
queryLog = []
with open('sessiontrack2014.xml') as fd:
    doc = xmltodict.parse(fd.read())
for x in range(1254):
    #print(type(doc['sessiontrack2014']['session'][x]['interaction']))
    if type(doc['sessiontrack2014']['session'][x]['interaction']) is list:
        for entry in (doc['sessiontrack2014']['session'][x]['interaction']):
            #print(type(entry))
            if not isinstance(entry, str):
                queryLog.append([x, entry['query'], entry['@starttime'], '', ''])
                if 'clicked' in entry.keys():
                    if type(entry['clicked']['click']) is list: 
                        #print('list')
                        for clicks in entry['clicked']['click']:
                            #print(clicks['rank'])
                            if int(clicks['rank'])-1 <10:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-1]['url']])
                            elif int(clicks['rank'])-1 <20:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-11]['url']])
                            elif int(clicks['rank'])-1 <30:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-21]['url']])
                            elif int(clicks['rank'])-1 <40:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-31]['url']])
                            elif int(clicks['rank'])-1 <50:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-41]['url']])
                            elif int(clicks['rank'])-1 <60:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-51]['url']])
                            elif int(clicks['rank'])-1 <70:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-61]['url']])
                            else:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-71]['url']])
                    else:
                        if (int(entry['clicked']['click']['rank'])-1) < 10:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-1]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 20:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-11]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 30:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-21]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 40:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-31]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 50:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-41]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 60:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-51]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 70:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-61]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 80:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-71]['url']])
                        else:  
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-81]['url']])
            else:
                print(entry)
    else:
        queryLog.append([x, doc['sessiontrack2014']['session'][x]['interaction']['query'], doc['sessiontrack2014']['session'][x]['interaction']['@starttime'], '', ''])
        if 'clicked' in doc['sessiontrack2014']['session'][x]['interaction'].keys():
            if type(doc['sessiontrack2014']['session'][x]['interaction']['clicked']['click']) is list: 
                for clicks in doc['sessiontrack2014']['session'][x]['interaction']['clicked']['click']:
                    queryLog.append([x, doc['sessiontrack2014']['session'][x]['interaction']['query'], clicks['@starttime'], clicks['rank'], doc['sessiontrack2014']['session'][x]['interaction']['results']['result'][int(clicks['rank'])-1]['url']]) 
                pass
            else:
                queryLog.append([x, doc['sessiontrack2014']['session'][x]['interaction']['query'], doc['sessiontrack2014']['session'][x]['interaction']['clicked']['click']['@starttime'], doc['sessiontrack2014']['session'][x]['interaction']['clicked']['click']['rank'], doc['sessiontrack2014']['session'][x]['interaction']['results']['result'][int(doc['sessiontrack2014']['session'][x]['interaction']['clicked']['click']['rank'])-1]['url']])

# %%
import xmltodict

with open('sessiontrack2013.xml') as fd:
    doc = xmltodict.parse(fd.read())
for x in range(132):
    #print(type(doc['sessiontrack2014']['session'][x]['interaction']))
    if type(doc['sessiontrack2013']['session'][x]['interaction']) is list:
        for entry in (doc['sessiontrack2013']['session'][x]['interaction']):
            #print(type(entry))
            if not isinstance(entry, str):
                queryLog.append([x, entry['query'], entry['@starttime'], '', ''])
                if 'clicked' in entry.keys():
                    if type(entry['clicked']['click']) is list: 
                        #print('list')
                        for clicks in entry['clicked']['click']:
                            #print(clicks['rank'])
                            if int(clicks['rank'])-1 <10:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-1]['url']])
                            elif int(clicks['rank'])-1 <20:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-11]['url']])
                            elif int(clicks['rank'])-1 <30:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-21]['url']])
                            elif int(clicks['rank'])-1 <40:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-31]['url']])
                            elif int(clicks['rank'])-1 <50:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-41]['url']])
                            elif int(clicks['rank'])-1 <60:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-51]['url']])
                            elif int(clicks['rank'])-1 <70:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-61]['url']])
                            else:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-71]['url']])
                    else:
                        #print(int(entry['clicked']['click']['rank'])-1)
                        if (int(entry['clicked']['click']['rank'])-1) < 10:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-1]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 20:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-11]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 30:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-21]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 40:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-31]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 50:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-41]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 60:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-51]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 70:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-61]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 80:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-71]['url']])
                        else:  
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-81]['url']])
            else:
                queryLog.append(entry)
    else:
        queryLog.append([x, doc['sessiontrack2013']['session'][x]['interaction']['query'], doc['sessiontrack2013']['session'][x]['interaction']['@starttime'], '', ''])
        if 'clicked' in doc['sessiontrack2013']['session'][x]['interaction'].keys():
            if type(doc['sessiontrack2013']['session'][x]['interaction']['clicked']['click']) is list: 
                for clicks in doc['sessiontrack2013']['session'][x]['interaction']['clicked']['click']:
                    queryLog.append([x, doc['sessiontrack2013']['session'][x]['interaction']['query'], clicks['@starttime'], clicks['rank'], doc['sessiontrack2013']['session'][x]['interaction']['results']['result'][int(clicks['rank'])-1]['url']]) 
                pass
            else:
                queryLog.append([x, doc['sessiontrack2013']['session'][x]['interaction']['query'], doc['sessiontrack2013']['session'][x]['interaction']['clicked']['click']['@starttime'], doc['sessiontrack2013']['session'][x]['interaction']['clicked']['click']['rank'], doc['sessiontrack2013']['session'][x]['interaction']['results']['result'][int(doc['sessiontrack2013']['session'][x]['interaction']['clicked']['click']['rank'])-1]['url']])

# %%
len(queryLog)
# Out:
# 6299

# %%
import xmltodict

with open('sessiontrack2012.xml') as fd:
    doc = xmltodict.parse(fd.read())
for x in range(97):
    #print(type(doc['sessiontrack2014']['session'][x]['interaction']))
    if type(doc['sessiontrack2012']['session'][x]['interaction']) is list:
        for entry in (doc['sessiontrack2012']['session'][x]['interaction']):
            #print(type(entry))
            if not isinstance(entry, str):
                queryLog.append([x, entry['query'], entry['@starttime'], '', ''])
                
                if 'clicked' in entry.keys():
                    if type(entry['clicked']) is None:
                        break
                    if type(entry['clicked']['click']) is list: 
                        #print('list')
                        for clicks in entry['clicked']['click']:
                            #print(clicks['rank'])
                            if int(clicks['rank'])-1 <10:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-1]['url']])
                            elif int(clicks['rank'])-1 <20:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-11]['url']])
                            elif int(clicks['rank'])-1 <30:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-21]['url']])
                            elif int(clicks['rank'])-1 <40:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-31]['url']])
                            elif int(clicks['rank'])-1 <50:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-41]['url']])
                            elif int(clicks['rank'])-1 <60:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-51]['url']])
                            elif int(clicks['rank'])-1 <70:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-61]['url']])
                            else:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-71]['url']])
                    else:
                        #print(int(entry['clicked']['click']['rank'])-1)
                        if (int(entry['clicked']['click']['rank'])-1) < 10:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-1]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 20:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-11]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 30:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-21]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 40:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-31]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 50:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-41]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 60:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-51]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 70:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-61]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 80:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-71]['url']])
                        else:  
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-81]['url']])
            else:
                print(entry)
    else:
        queryLog.append([x, doc['sessiontrack2012']['session'][x]['interaction']['query'], doc['sessiontrack2012']['session'][x]['interaction']['@starttime'], '', ''])
        if 'clicked' in doc['sessiontrack2012']['session'][x]['interaction'].keys():
            if type(doc['sessiontrack2012']['session'][x]['interaction']['clicked']['click']) is list: 
                for clicks in doc['sessiontrack2012']['session'][x]['interaction']['clicked']['click']:
                    queryLog.append([x, doc['sessiontrack2012']['session'][x]['interaction']['query'], clicks['@starttime'], clicks['rank'], doc['sessiontrack2012']['session'][x]['interaction']['results']['result'][int(clicks['rank'])-1]['url']]) 
                pass
            else:
                queryLog.append([x, doc['sessiontrack2012']['session'][x]['interaction']['query'], doc['sessiontrack2012']['session'][x]['interaction']['clicked']['click']['@starttime'], doc['sessiontrack2012']['session'][x]['interaction']['clicked']['click']['rank'], doc['sessiontrack2012']['session'][x]['interaction']['results']['result'][int(doc['sessiontrack2012']['session'][x]['interaction']['clicked']['click']['rank'])-1]['url']])

# %%
import xmltodict

with open('sessiontrack2011.xml') as fd:
    doc = xmltodict.parse(fd.read())
for x in range(75):
    #print(type(doc['sessiontrack2014']['session'][x]['interaction']))
    if type(doc['sessiontrack2011']['session'][x]['interaction']) is list:
        for entry in (doc['sessiontrack2011']['session'][x]['interaction']):
            #print(type(entry))
            if not isinstance(entry, str):
                queryLog.append([x, entry['query'], entry['@starttime'], '', ''])
                
                if 'clicked' in entry.keys():
                    if type(entry['clicked']) is None:
                        break
                    if type(entry['clicked']['click']) is list: 
                        #print('list')
                        for clicks in entry['clicked']['click']:
                            #print(clicks['rank'])
                            if int(clicks['rank'])-1 <10:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-1]['url']])
                            elif int(clicks['rank'])-1 <20:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-11]['url']])
                            elif int(clicks['rank'])-1 <30:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-21]['url']])
                            elif int(clicks['rank'])-1 <40:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-31]['url']])
                            elif int(clicks['rank'])-1 <50:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-41]['url']])
                            elif int(clicks['rank'])-1 <60:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-51]['url']])
                            elif int(clicks['rank'])-1 <70:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-61]['url']])
                            else:
                                queryLog.append([x, entry['query'], clicks['@starttime'], clicks['rank'], entry['results']['result'][int(clicks['rank'])-71]['url']])
                    else:
                        #print(int(entry['clicked']['click']['rank'])-1)
                        if (int(entry['clicked']['click']['rank'])-1) < 10:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-1]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 20:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-11]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 30:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-21]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 40:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-31]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 50:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-41]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 60:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-51]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 70:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-61]['url']])
                        elif (int(entry['clicked']['click']['rank'])-1) < 80:
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-71]['url']])
                        else:  
                            queryLog.append([x, entry['query'], entry['clicked']['click']['@starttime'], entry['clicked']['click']['rank'], entry['results']['result'][int(entry['clicked']['click']['rank'])-81]['url']])
            else:
                print(entry)
    else:
        queryLog.append([x, doc['sessiontrack2011']['session'][x]['interaction']['query'], doc['sessiontrack2011']['session'][x]['interaction']['@starttime'], '', ''])
        if 'clicked' in doc['sessiontrack2011']['session'][x]['interaction'].keys():
            if type(doc['sessiontrack2011']['session'][x]['interaction']['clicked']['click']) is list: 
                for clicks in doc['sessiontrack2011']['session'][x]['interaction']['clicked']['click']:
                    queryLog.append([x, doc['sessiontrack2011']['session'][x]['interaction']['query'], clicks['@starttime'], clicks['rank'], doc['sessiontrack2011']['session'][x]['interaction']['results']['result'][int(clicks['rank'])-1]['url']]) 
                pass
            else:
                queryLog.append([x, doc['sessiontrack2011']['session'][x]['interaction']['query'], doc['sessiontrack2011']['session'][x]['interaction']['clicked']['click']['@starttime'], doc['sessiontrack2011']['session'][x]['interaction']['clicked']['click']['rank'], doc['sessiontrack2011']['session'][x]['interaction']['results']['result'][int(doc['sessiontrack2011']['session'][x]['interaction']['clicked']['click']['rank'])-1]['url']])

# %%
currentUser = queryLog[0][0]
#currentTime = float(queryLog[0][2].replace('\'', ''))

# %%
sessions = []
session = []
for row in queryLog:
    print(row)
    tempUser = row[0]
    #tempTime = float(row[2].replace('\'', ''))
    if(tempUser != currentUser):
        sessions.append(session)
        session = []
        currentUser = tempUser
        #tempTime = float(row[2].replace('\'', ''))
        #currentTime = tempTime
    session.append(row)
# Out:
# [0, 'bollywood growth', '19.7867', '', '']
# [0, 'bollywood growth politics', '36.2614', '', '']
# [0, 'bollywood policies and legislation', '65.2176', '', '']
# [0, 'bollywood policies', '85.1155', '', '']
# [0, 'bollywood policies growth', '108.3693', '', '']
# [0, 'bollywood government', '137.3344', '', '']
# [0, 'bollywood government', '149.4158', '2', 'http://www.newsline365.com/20083035/uk-government-offers-tax-cuts-for-bollywood-ventures/']
# [1, 'Pocono Mountains vacation', '18.5407', '', '']
# [1, 'Pocono Mountains vacation', '26.2985', '1', 'http://www.masterpiecerentals.com/Pocono-Mountain-Lake-vacation-rentals-Pennsylvania.htm']
# [1, 'Pocono Mountains trip', '47.0526', '', '']
# [1, 'Pocono Mountains', '76.7741', '', '']
# [1, 'Pocono Mountains', '87.9928', '', '']
# [1, 'what do to in the Pocono Mountains', '102.8976', '', '']
# [1, 'what do to in the Pocono Mountains', '123.5461', '', '']
# [1, 'what do to in the Pocono Mountains', '147.1434', '', '']
# [1, 'what do to in the Pocono Mountains', '157.2608', '', '']
# [2, 'junk food trax', '8.9213', '', '']
# [2, 'junk food tax', '15.0574', '', '']
# [2, 'junk food tax', '23.7076', '2', 'http://www.huffingtonpost.com/2012/03/12/junk-food-taxes_n_1339530.html']
# [2, 'junk food tax', '79.2207', '4', 'https://www.copirg.org/media/cop/tax-dollars-subsidizing-junk-food']
# [2, 'junk food tax', '84.4852', '6', 'http://blog.sfgate.com/nov05election/2012/02/21/junk-food-taxes-reach-europe/']
# [2, 'junk food tax pros', '100.3409', '', '']
# [2, 'junk food tax pros', '131.6695', '2', 'http://miniatures.about.com/od/dollshousefood/ig/Dolls-House-Scale-Snack-Foods/']
# [2, 'junk food tax pros', '137.8892', '4', 'http://www.naturallifestyle.net/articles/Time-for-a-Junk-Food-Tax-2214']
# [2, 'junk food tax pros', '152.3190', '3', 'http://www.picturesindia.com/food-and-drink/junk-food/']
# [2, 'junk food tax pros', '160.4403', '5', 'http://www.gongol.com/opinion/2006/junkfoodinschools/']
# [3, 'dehumidifiers', '12.5718', '', '']
# [3, 'dehumidifiers', '16.3994', '1', 'http://www.allergymatters.com/acatalog/dehumidifier_review_dehumidifier_ratings.html']
# [4, 'health care in UK', '17.3871', '', '']
# [4, 'social security in UK', '50.9786', '', '']
# [4, 'US and UK safety nets', '70.4195', '', '']
# [5, 'kursk sink', '17.1256', '', '']
# [5, 'kursk  sub', '30.2785', '', '']
# [5, 'kursk  sub', '35.0955', '1', 'http://siberianlight.net/kursk-torpedoed-by-us-sub/']
# [5, 'kursk russia', '46.9660', '', '']
# [6, 'Red Bull health concerns', '41.8873', '', '']
# [6, 'Red Bull health concerns', '47.7557', '3', 'http://www.redbull.com']
# [6, 'Red Bull health concerns', '57.0145', '', '']
# [6, 'Red Bull health concerns', '71.0410', '', '']
# [6, 'Red Bull health concerns', '82.4890', '', '']
# [6, 'Red Bull health concerns', '89.9066', '', '']
# [6, 'Red Bull health concerns', '101.8944', '', '']
# [6, 'Red Bull health concerns', '117.0253', '', '']
# [6, 'Red Bull health concerns', '140.3037', '', '']
# [6, 'Red Bull health concerns', '150.3552', '', '']
# [6, 'Red Bull health concerns', '162.8812', '', '']
# [7, 'gun control', '183.4574', '', '']
# [8, 'non-profit organization', '88.3703', '', '']
# [9, 'African HIV charities', '28.5554', '', '']
# [9, 'African HIV charities', '39.1662', '3', 'http://www.info.gov.za/otherdocs/2007/aidsplan2007/index.html']
# [9, 'African HIV charities', '76.3084', '4', 'http://www.bioafrica.net/saturn/']
# [9, 'African HIV charities', '113.1506', '6', 'http://aids.about.com/cs/aidsfactsheets/a/africa.htm']
# [9, 'African HIV charities', '129.4892', '10', 'http://aids.about.com/od/clinicaltrials/a/safrica.htm']
# [9, 'African charities', '148.9405', '', '']
# [10, 'internet phone service benifits', '27.7019', '', '']
# [10, 'what make internet phone service great', '49.0794', '', '']
# [10, 'internet phone service advantages', '78.3439', '', '']
# [10, 'internet phone service selection advice', '107.2852', '', '']
# [11, 'hawaii vacation', '23.0335', '', '']
# [11, 'hawaii vacation', '27.3142', '3', 'http://www.hawaii.com']
# [11, 'hawaii vacation', '36.9759', '6', 'http://www.blue-hawaii.com']
# [11, 'seattle vacation', '44.9671', '', '']
# [11, 'seattle vacation', '49.5437', '3', 'http://www.fareconnect.com/index.php?pageId=109']
# [11, 'canada vacation', '62.1444', '', '']
# [11, 'canada vacation', '67.4055', '1', 'http://www.rental-vacation.net']
# [11, 'paris vacation', '79.3294', '', '']
# [12, 'Smoking qutting tips', '44', '', '']
# [12, 'reddit smoking quitting', '57', '', '']
# [12, 'reddit smoking quitting', '71', '3', 'http://www.quitsmokingsupport.com/tools.htm']
# [12, 'reddit smoking quitting', '76', '1', 'http://www.smokefree.gov']
# [12, 'reddit smoking quitting', '85', '4', 'http://quitsmoking.about.com/cs/afterquitting/a/after_quitting.htm']
# [12, 'no more smoking', '124', '', '']
# [13, 'Swahili dishes guide', '111.9556', '', '']
# [13, 'Swahili traditional food guide', '174.9913', '', '']
# [13, 'Swahili traditional food guide', '261.6145', '', '']
# [14, 'philedelphia travel guide', '65.7512', '', '']
# [14, 'philedelphia travel guide', '87.5870', '', '']
# [14, 'what to see around philedelphia', '128.7622', '', '']
# [14, 'what to see around philedelphia', '145.0425', '', '']
# [15, 'Teacher peer evaluation', '28.5418', '', '']
# [15, 'Teacher peer evaluation', '80.7279', '3', 'http://academicaffairs.uoregon.edu/peer-evaluation-teaching-and-learning']
# [15, 'Teacher peer evaluation', '87.5658', '', '']
# [15, 'Students evaluation of teachers', '110.8359', '', '']
# [15, 'Students evaluation of teachers', '138.9857', '1', 'http://www.tqsource.org/webcasts/evaluatingTeachers/index.php']
# [15, 'Students evaluation of teachers', '145.4133', '', '']
# [15, 'Students evaluation of teachers', '169.7102', '4', 'http://www.baruch.cuny.edu/studentaffairs/StudentLife/evaluations/index.htm']
# [16, '403 vs IRA', '16.1221', '', '']
# [16, '403(b) advantages', '47.3671', '', '']
# [16, 'IRA advantages', '75.0790', '', '']
# [16, 'IRA adisadvangtages', '112.4168', '', '']
# [16, 'IRAadisadvangtages', '118.1906', '', '']
# [16, 'IRA disadvangtages', '122.5568', '', '']
# [16, 'Which is better 403(b) or an IRA?', '138.5249', '', '']
# [17, 'Swahili food', '11.4381', '', '']
# [17, 'Swahili food', '17.1991', '8', 'http://kikuyumoja.com/2009/01/08/the-diet/']
# [18, 'france world cup 1998', '23.1363', '', '']
# [18, 'what happened after france won world cup 1998', '49.3476', '', '']
# [18, 'france world cup 1998 reactions', '72.6287', '', '']
# [18, 'france world cup 1998 reactions', '79.5720', '', '']
# [18, 'france world cup 1998 reaction', '107.8226', '', '']
# [19, 'Training at connecticut fire academy', '91.2459', '', '']
# [20, 'famous scientific glass blowing', '27.6992', '', '']
# [20, 'famous scientific glass blowing', '35.4641', '1', 'http://www.grahamstownhandbook.co.za/sub_category.asp?id=146']
# [20, 'famous scientific glass blowing', '46.4075', '2', 'http://www.holstengalleries.com/artists']
# [20, 'famous scientific glass blowing', '55.5756', '3', 'http://www.alanmacfarlane.com/global/england1404.htm']
# [20, 'famous scientific glass blowing', '62.9019', '4', 'http://www.chem.purdue.edu/glasslab/index.html']
# [20, 'famous scientific glass blowing', '82.0754', '', '']
# [20, 'glass blowing in history', '132.8118', '', '']
# [20, 'glass blowing in history', '138.7523', '', '']
# [21, 'bollywood legislation', '13.2538', '', '']
# [21, 'growth in bollywood', '39.3310', '', '']
# [21, 'growth in bollywood government', '52.4568', '', '']
# [21, 'india government bollywood', '71.0225', '', '']
# [21, 'india growth bollywood', '106.5149', '', '']
# [22, 'swahili food', '11.5360', '', '']
# [22, 'swahili recipes', '28.3809', '', '']
# [22, 'traditional swahili recipes', '59.5386', '', '']
# [22, 'traditional swahili recipes', '75.4052', '1', 'http://www.the-doctors.info/food_and_drink/13027.html']
# [22, 'traditional swahili food', '126.4680', '', '']
# [23, 'Connecticut fire academy', '15.7802', '', '']
# [23, 'Connecticut fire academy', '29.5360', '4', 'http://www.ctcase.org']
# [23, 'Connecticut firemen academy', '69.2405', '', '']
# [23, 'Connecticut firemen school', '88.0383', '', '']
# [24, 'WEIGHT LOSS POSSIBILITIES', '25.9718', '', '']
# [24, 'WEIGHT LOSS POSSIBILITIES', '50.0351', '', '']
# [25, 'Kursk Sinking', '33.1137', '', '']
# [25, 'Kursk Wikipedia', '52.7705', '', '']
# [25, 'Kursk', '105.7388', '', '']
# [25, 'Kursk Submarine How many crewman lost', '128.9989', '', '']
# [26, 'Merck and Co. lobbying', '12.3543', '', '']
# [26, 'Merck and Co. lobbying', '16.1574', '2', 'http://informedvoters.wordpress.com/2007/02/20/merck-admits-it-was-wrong-to-lobby-for-making-hpv-vaccine-mandatory/']
# [26, 'Merck and Co. lobbying', '19.2985', '3', 'http://womenshealthnews.wordpress.com/2007/02/21/merck-to-stop-lobbying-for-mandatory-hpv-vaccines/']
# [26, 'Merck and Co. lobbying', '81.0115', '1', 'http://www.kbtx.com/home/headlines/5546651.html']
# [26, 'Merck and Co. legislation', '77.6638', '', '']
# [27, 'collagen vascular disease', '31.7466', '', '']
# [28, 'pseudocyesis information', '18.8255', '', '']
# [28, 'pseudocyesis information', '48.2607', '1', 'http://womenshealth.about.com/od/womenshealthglossary/g/pseudocyesis.htm']
# [28, 'pseudocyesis advances', '55.4887', '', '']
# [28, 'pseudocyesis advances false pregnancy psychology', '64.0532', '', '']
# [28, 'pseudocyesis advances in medicine', '86.7993', '', '']
# [28, 'pseudocyesis developments', '106.9324', '', '']
# [28, 'pseudocyesis developments', '112.3043', '2', 'http://hdr.undp.org']
# [28, 'pseudocyesis recent developments', '128.8048', '', '']
# [28, 'recent developments in pseudocyesis', '140.8312', '', '']
# [29, 'breeding dogs', '10.5642', '', '']
# [29, 'breeding dogs', '18.3289', '1', 'http://www.miniature-schnauzer-australia.com/dog_breeding_information.html']
# [29, 'breeding dogs', '56.7077', '2', 'http://www.husky-petlove.com/husky_calendar.html']
# [29, 'breeding dogs', '65.5846', '4', 'http://www.pedigreedpups.com/dogarticles.html']
# [30, 'how does hydoelectric power work', '24.7029', '', '']
# [30, 'hydoelectric power', '52.8483', '', '']
# [30, 'hydropower', '73.1579', '', '']
# [30, 'hydropower', '80.5867', '3', 'http://www.hydropower-dams.com']
# [30, 'hydropower', '107.7806', '7', 'http://www.wvic.com/hydro-facts.htm']
# [30, 'hydropower', '114.1897', '10', 'http://environment.nationalgeographic.com/environment/global-warming/hydropower-profile/']
# [30, 'hydropower', '209.6179', '', '']
# [30, 'hydropower damns', '220.8133', '', '']
# [30, 'hydropower damns', '235.5016', '', '']
# [30, "why isn't hydropower used more often", '253.0609', '', '']
# [30, "why isn't hydropower used more often", '270.3518', '', '']
# [31, 'dehumidifiers', '16.5596', '', '']
# [31, 'dehumidifiers best value', '35.6251', '', '']
# [31, 'dehumidifiers best value', '55.8674', '5', 'http://www.inlightcenter.com/make-life-easy-and-purchase-the-best-dehumidifier-online/258/']
# [31, 'dehumidifiers reviews best value', '102.1984', '', '']
# [31, 'dehumidifiers reviews low cost', '145.1530', '', '']
# [32, 'best internet phone services', '10.4767', '', '']
# [32, 'best internet phone services', '22.8544', '4', 'http://azizzii.hubpages.com/hub/Finding-the-best-Internet-Phone-Service-Provider']
# [32, 'best internet phone services', '28.3400', '5', 'http://www.comparetvpackages.com/qa-whats-the-best-package-deal-for-internet-phone-cablesatellite-tv-service-around-the-nyc-area/']
# [32, 'best internet phone services', '38.6040', '7', 'http://jentoono.com/internetproviders/how-to-choose-the-best-voip-internet-digital-phone-service-provider-voice-over-internet-protocol/']
# [32, 'best internet phone services', '45.7706', '9', 'http://www.seoschoolbus.com/best-internet-phone-service-review']
# [32, 'cheapest internet phone services', '93.3294', '', '']
# [32, 'cheapest internet phone services', '116.1376', '8', 'http://austenbookz.info/internet-phone-services-simplified-voip-jim-doherty-neil-anderson-ebook/']
# [32, 'cheapest internet phone services', '122.4659', '10', 'http://www.viatalk.com']
# [32, 'providers of VOIP', '133.9618', '', '']
# [32, 'providers of VOIP list', '172.4713', '', '']
# [32, 'providers of VOIP list', '185.8997', '2', 'http://www.voip-info.org/wiki/view/VOIP+Service+Providers']
# [32, 'features that great VOIP services', '216.6273', '', '']
# [32, 'features that great VOIP services', '240.7773', '6', 'http://www.appscorp.net/voip_phone_system.asp']
# [32, 'features that great VOIP services', '245.8787', '4', 'http://www.voip.com.sg']
# [32, 'features that great VOIP services', '271.2119', '1', 'http://www.vbuzzer.com']
# [32, 'free calls from the US to some European countries voip', '301.8061', '', '']
# [32, 'free calls from the US to some European countries voip', '317.3875', '3', 'http://www.moneysavingexpert.com/phones/free-international-phone-calls']
# [33, 'location of port arthur', '14.5193', '', '']
# [33, 'location of port arthur massacre', '32.2008', '', '']
# [33, 'location of port arthur massacre', '43.2322', '2', 'http://www.russojapanesewar.com/portarthur1894.html']
# [33, 'what happened at the Port Arthur Massacre', '84.2355', '', '']
# [33, 'Port Arthur Massacre australia', '112.7123', '', '']
# [33, 'Port Arthur Massacre australia', '119.0887', '1', 'http://truthcanada.freeforums.org/australia-s-911-the-port-arthur-massacre-t845.html']
# [34, 'philedelphia travel guide', '234.7421', '', '']
# [34, 'what to see around philedelphia', '254.5548', '', '']
# [35, 'cause of eurozone crisi', '47.1988', '', '']
# [35, 'cause of eurozone crisi', '52.0537', '', '']
# [36, 'traditional swahili dishes', '35.2199', '', '']
# [36, 'traditional swahili dishes', '76.2769', '', '']
# [36, 'traditional swahili dishes', '92.0012', '', '']
# [36, 'traditional swahili dishes', '95.6536', '', '']
# [36, 'traditional swahili dishes', '102.7248', '', '']
# [37, 'Face transplants', '10.9483', '', '']
# [37, 'Face transplants', '13.4938', '1', 'http://www.bbc.co.uk/news/world-us-canada-17534646']
# [37, 'Face transplants', '82.3851', '5', 'http://vitals.msnbc.msn.com/_news/2012/03/27/10888074-virginia-man-gets-extensive-face-transplant-after-gun-accident']
# [37, 'Face transplants', '88.1585', '3', 'http://www.bbc.co.uk/news/world-us-canada-17532303']
# [37, 'Face transplants', '94.7133', '7', 'http://www.bbc.co.uk/news/health-15863721']
# [37, 'Face transplants', '102.3347', '6', 'http://vitals.msnbc.msn.com/_news/2012/04/03/11001075-a-year-after-full-face-transplant-dallas-wiens-feels-almost-normal']
# [37, 'Face transplants', '114.7895', '9', 'http://www.yourplasticsurgeryguide.com/reconstructive/face-transplant.htm']
# [38, 'Kursk', '22.3709', '', '']
# [38, 'Submarine Kursk', '34.7909', '', '']
# [38, 'Submarine Kursk', '39.0005', '2', 'http://www.monacorarecoins.com/rare-coin-articles/kursk/']
# [38, 'Russian Submarine Kursk', '64.5188', '', '']
# [38, 'Russian Submarine Kursk', '80.0771', '3', 'http://www.monacorarecoins.com/rare-coin-articles/kursk/']
# [38, 'Russian Submarine Kursk', '91.1824', '4', 'http://history1900s.about.com/od/1990s/qt/Kursk.htm']
# [38, 'Russian Submarine Kursk', '100.6218', '', '']
# [38, 'Russian Submarine Kursk Commander', '108.6546', '', '']
# [38, 'Russian Submarine Kursk Commander', '115.8534', '', '']
# [38, 'Russian Submarine Kursk Commander', '119.2653', '1', 'http://soviet-uniforms.com/items/awards/_36/36.html']
# [38, 'Kursk Countries', '149.1847', '', '']
# [39, 'side effects of Red Bull', '32.7944', '', '']
# [39, 'US laws proposing a ban on drinks like Red Bull', '85.1302', '', '']
# [39, 'ingredients of redbull', '115.8534', '', '']
# [39, 'ingredients of redbull', '149.3239', '', '']
# [40, 'glass science advances', '49.6928', '', '']
# [40, 'glass science history', '123.2634', '', '']
# [40, 'glass science history', '148.9867', '', '']
# [41, 'what to do if a friend has depression', '16.4761', '', '']
# [41, 'helping someone with depression', '39.1171', '', '']
# [41, 'medical referrals for depression', '71.8879', '', '']
# [41, 'psychologists', '84.7910', '', '']
# [42, 'collagen vascular disease', '9.2219', '', '']
# [42, 'collagen vascular disease', '11.0961', '1', 'http://www.myoptumhealth.com/portal/ADAM/item/Collagen+vascular+disease']
# [42, 'collagen vascular disease', '20.4731', '2', 'http://www.humanillnesses.com/original/Cank-Con/Collagen-Vascular-Diseases.html']
# [42, 'collagen vascular disease sports', '76.6149', '', '']
# [42, 'collagen vascular disease lifestyle', '87.0918', '', '']
# [42, 'collagen vascular disease lifestyle', '90.4310', '4', 'http://faculty.insead.edu/parker/resume/Browse/Health/Collagen-vascular_disease_cataracts_(caused_by_lupus).html']
# [42, 'collagen vascular disease lifestyle', '140.3971', '10', 'http://www.aaps1921.org/abstracts/2010/P12.cgi']
# [42, 'collagen vascular disease guide', '135.1448', '', '']
# [43, 'European economic issues', '32.3690', '', '']
# [43, 'Cyprus economic issues.', '51.8874', '', '']
# [43, 'Cyprus economic crisis', '79.5700', '', '']
# [43, 'Cyprus economic crisis', '103.1758', '2', 'http://cns.miis.edu/cyprus/index.htm']
# [44, 'junk food', '21', '', '']
# [44, 'junk food', '29', '3', 'http://www.everytherapist.com/blog/are-we-giving-children-mixed-messages-about-food-awareness/']
# [44, 'junk food', '37', '4', 'http://naturalhealthperspective.com/food/processedfood.html']
# [44, 'junk food', '49', '5', 'http://www.fastcompany.com/magazine/154/the-new-junk-food.html']
# [44, 'junk food', '75', '6', 'http://purpleperl.hubpages.com/hub/Top-5-Junk-Food-To-Avoid']
# [44, 'junk food', '110', '8', 'http://www.dumblittleman.com/2008/05/how-to-kill-your-addictions-to-junk.html']
# [45, 'WHICH IS BEST COUNTRY FOR WORKING US OR UK', '49.7650', '', '']
# [45, 'safety nets', '75.8021', '', '']
# [45, 'WHICH COUNTRY IS SAFETY NETS FOR WORKING JOB US OR UK', '96.3339', '', '']
# [46, 'teacher peer evaluations', '12.7560', '', '']
# [46, 'teacher peer evaluations', '15.1456', '', '']
# [46, 'teacher peer evaluations', '22.2924', '', '']
# [46, 'teacher peer evaluations', '30.6472', '3', 'http://www.teachingquality.org/newmillennium/toolkits/eval-teach-effect']
# [47, 'designer dog', '41.6876', '', '']
# [48, 'Voip', '11.6779', '', '']
# [48, 'voip features', '22.8887', '', '']
# [48, 'voip features', '27.6892', '2', 'http://voip.about.com/od/voipfeatures/a/featuresvoip.htm']
# [48, 'voip providers', '72.0684', '', '']
# [48, 'voip reviews', '88.8568', '', '']
# [48, 'voip reviews', '94.8606', '2', 'http://www.voipreview.org']
# [48, 'cheapest voip', '148.5356', '', '']
# [49, 'Pocono Mountains region', '17.3629', '', '']
# [49, 'Pocono Mountains region', '24.6154', '1', 'http://forum.pafoa.org/pocono-mountain-region-65/']
# [49, 'Pocono Mountains region nation parks', '48.1321', '', '']
# [49, 'Pocono Mountains region nation parks', '63.9521', '2', 'http://www.babymoonguide.com/pocono-mountains-pennsylvania-babymoon.html']
# [49, 'Pocono Mountains region nation parks', '88.5307', '3', 'http://www.babymoonguide.com/pocono-mountains-pennsylvania-babymoon-caesars-resorts.html']
# [49, 'National Parks at Pocono Mountains region', '113.1755', '', '']
# [49, 'National Parks at Pocono Mountains region', '137.6479', '8', 'http://www.pocono.org/poconocoupon-pocono-poconos-scranton-attraction-mountains.html']
# [50, 'teacher peer evaluation', '42.1236', '', '']
# [50, 'teacher peer evaluation', '66.3687', '6', 'http://www.rethinkingschools.org/special_reports/quality_teachers/uneval.shtml']
# [50, 'students evaluating teachers', '89.9728', '', '']
# [50, 'students evaluating teachers', '127.0908', '', '']
# [51, 'hydropower efficiency', '21.0060', '', '']
# [51, 'hydropower efficiency', '29.5423', '2', 'http://www.lawofrenewableenergy.com/2011/12/articles/hydropower/hydropower-regulatory-efficiency-act-of-2011-introduced-in-the-house-of-representatives/']
# [51, 'hydropower environment', '143.4412', '', '']
# [51, 'hydropower environment', '149.4412', '2', 'http://www.ieahydro.org/Hydro___The_Environment6.html']
# [52, 'submarine Kursk wiki', '19.7026', '', '']
# [52, 'submarine Kursk political effect', '37.2953', '', '']
# [52, 'submarine Kursk and cold war', '107.8718', '', '']
# [53, 'kenya swahili food', '16.7606', '', '']
# [53, 'kenya swahili recipes', '28.3658', '', '']
# [53, 'kenya recipes', '40.9630', '', '']
# [53, 'kenya recipes', '48.6222', '1', 'http://www.kenyatravelideas.com/kenya-recipes.html']
# [53, 'kenya recipes', '70.1331', '2', 'http://www.kenya-advisor.com/kenya-food-recipes.html']
# [53, 'traditional kenya recipes', '128.2311', '', '']
# [54, 'French reaction to winning the World Cup in 1998', '28.0640', '', '']
# [54, 'French reaction to winning the World Cup in 1998', '48.1049', '2', 'http://football-en.footforever.com/CM/Editions_CM/france_1998_edi_cm.php']
# [54, 'France World Cup 1998', '102.1791', '', '']
# [54, 'France World Cup 1998', '110.0137', '5', 'http://www.frenchlinks.org.uk/france98/WCindex.html']
# [54, 'French reaction to winning the world cup', '145.3325', '', '']
# [54, 'France World Cup 1998', '151.9864', '', '']
# [54, 'France World Cup 1998', '167.5947', '', '']
# [54, 'France World Cup 1998', '180.2265', '', '']
# [54, 'French citizens reaction to winning the World Cup 1998', '197.2599', '', '']
# [55, 'red bull side effects', '9.9323', '', '']
# [55, 'red bull side effects', '45.0970', '1', 'http://www.s2s.co.za/2012/02/28/red-bull-energy-drink-and-its-side-effects/']
# [55, 'red bull bad', '64.3795', '', '']
# [56, 'women employees percentage', '39.5628', '', '']
# [56, 'women and minority employees percentage', '146.1318', '', '']
# [56, 'minority employees percentage', '154.6059', '', '']
# [56, 'minority employees', '163.2115', '', '']
# [57, 'dallas airports', '17.5112', '', '']
# [57, 'dallas airports', '22.0471', '1', 'http://www.aboutairportparking.com/dallasfort-worth-international-airport-parking']
# [57, 'dallas airports', '27.0495', '2', 'http://www.austin-ind.com/commercial/experience/browse-projects/projects/dfw-international-terminal-d']
# [57, 'dallas airports hotel area', '72.6867', '', '']
# [57, 'dallas airports hotel area', '79.9686', '7', 'http://www.therouteshop.com/coming-soon.php']
# [58, 'how to tell if someone is depressed', '19.4822', '', '']
# [58, 'how to tell if someone is depressed', '37.3941', '9', 'http://depression.about.com/cs/basicfacts/ht/Help_Depressed.htm']
# [58, 'how to help someone who is depressed', '91.7921', '', '']
# [58, 'how to help someone who is depressed', '101.9457', '1', 'http://depression.about.com/cs/basicfacts/a/howtohelp.htm']
# [58, 'how to help someone who is depressed', '162.7045', '', '']
# [59, 'newborn milestones asian', '50.4452', '', '']
# [59, 'newborn milestones japan', '70.7080', '', '']
# [59, 'newborn milestones china', '80.7768', '', '']
# [59, 'japan infant milestones', '103.2821', '', '']
# [59, 'china infant milestones', '132.3831', '', '']
# [60, 'portugal eurozone', '19.2107', '', '']
# [60, 'portugal eurozone', '37.5722', '1', 'http://www.guardian.co.uk/business/2012/feb/28/eurozone-crisis-greek-downgrade']
# [61, 'dehumidifier', '14.3047', '', '']
# [61, 'dehumidifier', '18.0792', '1', 'http://www.allergymatters.com/acatalog/dehumidifier_review_dehumidifier_ratings.html']
# [61, 'dehumidifier prices', '44.6918', '', '']
# [61, 'dehumidifier prices amazon', '51.5415', '', '']
# [61, 'dehumidifier specs', '62.7736', '', '']
# [62, 'women employees and minority employees', '52.8212', '', '']
# [63, 'collagen vascular disease', '23.2604', '', '']
# [63, 'collagen vascular disease', '31.7449', '2', 'http://www.humanillnesses.com/original/Cank-Con/Collagen-Vascular-Diseases.html']
# [63, 'collagen vascular disease', '39.4888', '1', 'http://www.myoptumhealth.com/portal/ADAM/item/Collagen+vascular+disease']
# [63, 'collagen vascular disease', '54.2245', '4', 'http://arapaho.nsuok.edu/~castillo/Collagen-vasculardiseases.html']
# [63, 'collagen vascular disease', '60.4805', '5', 'http://arapaho.nsuok.edu/%7Ecastillo/Collagen-vasculardiseases.html']
# [63, 'collagen vascular disease', '68.7746', '3', 'http://faculty.insead.edu/parker/resume/Browse/Health/Collagen-vascular_disease_cataracts_(caused_by_lupus).html']
# [63, 'collagen vascular disease', '83.7217', '1', 'http://www.myoptumhealth.com/portal/ADAM/item/Collagen+vascular+disease']
# [63, 'types of collagen vascular disease', '97.1560', '', '']
# [63, 'types of collagen vascular disease', '101.5318', '', '']
# [63, 'types of collagen vascular disease', '108.7191', '', '']
# [63, 'types of collagen vascular disease', '114.9656', '1', 'http://arapaho.nsuok.edu/%7Ecastillo/Collagen-vasculardiseases.html']
# [63, 'types of collagen vascular disease', '119.1290', '2', 'http://arapaho.nsuok.edu/~castillo/Collagen-vasculardiseases.html']
# [63, 'types of collagen vascular disease', '123.8679', '3', 'http://www.aaps1921.org/abstracts/2010/P12.cgi']
# [63, 'types of collagen vascular disease', '145.5485', '5', 'http://www.washingtonadventisthospital.com/adam/HIE%20Multimedia/1/001223.html']
# [63, 'types of collagen vascular disease', '154.3796', '4', 'http://www.adventisthealthcare.com/adam/HIE%20Multimedia/1/001223.html']
# [64, 'bollywood', '8.5920', '', '']
# [64, 'bollywood', '13.3623', '1', 'http://blog.desishock.net/category/bollywood-newsgossips-and-review/']
# [64, 'bollywood location', '43.7898', '', '']
# [64, 'bollywood name origin', '60.6228', '', '']
# [64, 'bollywood name meaning', '70.4549', '', '']
# [64, 'bollywood stars', '83.0594', '', '']
# [64, 'bollywood stars', '87.1916', '3', 'http://www.youthgossip.com/bollywood-actor-ranbir-kapoor-star-ishq-remake.html']
# [64, 'why is it called bollywood', '120.1730', '', '']
# [64, 'why is it called bollywood', '131.3746', '', '']
# [65, 'gun control and its effects on gun violence', '30.6010', '', '']
# [65, 'gun control and its effects on gun violence', '56.5956', '1', 'http://commonsenseconspiracy.com/2012/04/trayvon-martin-and-gun-violence-setting-the-stage-for-gun-control-in-obamas-second-term/']
# [65, 'gun control and its effects on gun violence', '133.1478', '3', 'http://www.emergencypreparationforum.com/the-effects-of-gun-control-631.html']
# [65, 'gun control and its effects on gun violence', '147.4757', '4', 'http://dawn.thot.net/gun_control.html']
# [65, 'gun control and its effects on gun violence', '166.2468', '', '']
# [65, 'gun control and its effects on gun violence', '170.6568', '11', 'http://www.iansa.org']
# [65, 'gun control and its effects on gun violence', '196.0979', '', '']
# [65, 'gun control and its effects on gun violence', '202.5872', '21', 'http://www.issues2000.org/Background_Gun_Control.htm']
# [65, 'gun control and its effects on gun violence', '221.0186', '29', 'http://crime.about.com/od/guns/Weapons_and_Gun_Control.htm']
# [65, 'gun control and its effects on gun violence', '243.8534', '', '']
# [65, 'gun control and its effects on gun violence', '247.4817', '', '']
# [65, 'gun control and its effects on gun violence', '259.5972', '39', 'http://usgovinfo.about.com/library/weekly/aa030500a.htm']
# [66, 'Indian politics behind miss universe win', '86.5132', '', '']
# [66, 'Indian miss universe political issues.', '123.2863', '', '']
# [67, 'Churchill Downs', '22.1824', '', '']
# [67, 'Churchill Downs', '33.4081', '', '']
# [67, 'Churchill Downs seating', '61.0540', '', '']
# [67, 'Kentucky Derby museum', '93.8193', '', '']
# [67, 'Churchill Downs breeders cup', '108.4672', '', '']
# [67, 'Churchill Downs breeders cup', '145.4869', '', '']
# [67, 'Churchill  breeders cup', '159.1770', '', '']
# [68, 'Indian miss world competitions', '15.0546', '', '']
# [68, 'Indian government miss world', '33.5191', '', '']
# [68, 'Indian governmental policy miss universe', '66.4788', '', '']
# [68, 'Indian governmental policy miss universe', '122.8622', '', '']
# [68, 'Indian miss universse', '152.0601', '', '']
# [69, 'JP morgan chase history', '36.3933', '', '']
# [69, 'JP morgan chase history', '49.2769', '3', 'http://www.jpmorgan.com/pages/jpmorgan']
# [70, 'evaluating empoyess', '27.6622', '', '']
# [70, 'evaluating empoyess', '32.4003', '', '']
# [71, 'Are dehumidifiers good value for money', '29.7043', '', '']
# [71, 'dehumidifiers benefits', '70.5154', '', '']
# [71, 'dehumidifiers benefits', '102.3434', '9', 'http://www.sylvane.com']
# [71, 'dehumidifiers buying guide', '158.0743', '', '']
# [71, 'dehumidifiers buying guide', '192.5170', '1', 'http://www.airdehumidifier.com/Articles/Air_dehumidifier_buying_Guide.php']
# [71, 'dehumidifiers advantages', '218.3262', '', '']
# [72, 'how to evaluate employees properly', '17.7897', '', '']
# [72, 'how to evaluate employees properly', '34.9668', '6', 'http://www.halogensoftware.com/products/halogen-eappraisal/employee-evaluation-forms/']
# [72, 'evaluating employee tactics', '71.6430', '', '']
# [72, 'evaluating employee tactics', '82.5004', '5', 'http://www.jdtplaw.com/article/20110901-smart-business-magazine-should-companies-eliminate-traditional-employee-evaluation']
# [72, 'evaluating employee tactics', '97.9357', '6', 'http://humanresources.about.com/od/performancemanagement/a/self_evaluation.htm']
# [72, 'evaluating employee tips', '118.8026', '', '']
# [72, 'evaluating employee tips', '135.0537', '2', 'http://www.articlegurus.com/tips-on-how-to-evaluate-employees-for-a-performance-appraisal/']
# [72, 'evaluating employee tips', '146.0628', '8', 'http://www.halogensoftware.com/products/halogen-eappraisal/']
# [72, 'evaluating employee tips', '160.7203', '', '']
# [73, 'evidence of gods existence', '113.3086', '', '']
# [74, 'internet phone services', '43.2335', '', '']
# [74, 'internet phone services', '63.5003', '1', 'http://austenbookz.info/internet-phone-services-simplified-voip-jim-doherty-neil-anderson-ebook/']
# [74, 'internet phone services', '73.5643', '', '']
# [74, 'internet phone services', '225.0644', '', '']
# [75, 'What is silicone roof coating?', '16.0949', '', '']
# [75, 'What is silicone roof coating?', '18.5894', '1', 'http://www.weatherstarcoatings.com/pages/products/AWSPDS410.html']
# [75, 'What is the best material to use if the purpose is cooling down the roof so that the house temperature remains low?', '82.6303', '', '']
# [76, 'toursim placess in the united states', '32.3206', '', '']
# [76, 'toursim placess in the united states', '34.7991', '', '']
# [76, 'toursim placess in the united states', '39.5885', '', '']
# [76, 'toursim placess in the united states', '59.6368', '4', 'http://www.access.gpo.gov/congress/senate/constitution/toc.html']
# [76, 'toursim placess in the united states', '88.1109', '8', 'http://www.census.gov/population/www/documentation/twps0027.html']
# [76, 'toursim placess in the united states', '111.1598', '8', 'http://www.census.gov/population/www/documentation/twps0027.html']
# [76, 'toursim placess in the united states', '119.8539', '', '']
# [77, 'Poconos vacation', '99.2229', '', '']
# [77, 'Poconos vacation', '115.4155', '1', 'http://www.poconosgetaways.com/index.shtml']
# [77, 'Poconos vacation', '147.0205', '2', 'http://www.poconosrentalplaces.com']
# [77, 'Poconos activities', '157.8998', '', '']
# [77, 'Poconos activities', '164.4084', '6', 'http://www.mountaingetaway.com/poconos/events/']
# [77, 'Poconos fishing', '181.6212', '', '']
# [77, 'Poconos mountain fishing', '193.0491', '', '']
# [77, 'Pocono mountain fishing', '196.9521', '', '']
# [78, 'development stages of infants in east asia', '27.6862', '', '']
# [78, 'development stages of infants in east asia', '36.9890', '1', 'http://adfisroma.angelfire.com/asian.infant.feeding.practices..html']
# [78, 'east asain child development', '83.1310', '', '']
# [78, 'east asian child development', '90.5392', '', '']
# [78, 'east asian child development', '102.1481', '1', 'http://www.searo.who.int']
# [78, 'east asian child milestones', '162.6109', '', '']
# [78, 'east asian development milestones', '180.1066', '', '']
# [78, 'east asian development milestones', '193.6329', '4', 'http://ealc.uchicago.edu']
# [79, 'air conditioning', '61.1035', '', '']
# [80, 'Connecticut Fire Academy training', '105.7984', '', '']
# [81, 'designer dogs pros and cons', '14.7146', '', '']
# [81, 'designer dogs pros and cons', '22.6731', '1', 'http://www.dummies.com/how-to/content/exploring-the-pros-and-cons-of-designer-dogs.html']
# [81, 'designer dogs benefits', '48.9315', '', '']
# [81, 'designer dogs benefits', '77.4332', '3', 'http://www.teacupspuppies.com/teacupdogclothes.htm']
# [81, 'designer dog status symbol', '88.5567', '', '']
# [81, 'designer dog status symbol', '101.2451', '7', 'http://www.designermixes.org']
# [81, 'designer dog cons', '160.9814', '', '']
# [82, 'kenya food', '44.9462', '', '']
# [82, 'kenya dish', '59.8494', '', '']
# [82, 'kenya recipe', '69.7602', '', '']
# [82, 'kenya recipe', '80.7510', '2', 'http://www.kenya-advisor.com/kenya-food-recipes.html']
# [82, 'kenya recipe', '87.5286', '4', 'http://www.easy-kids-recipes.com/kenya-recipes.html']
# [83, 'Merck lobbying', '16.7678', '', '']
# [83, 'Merck lobbying', '23.7187', '1', 'http://informedvoters.wordpress.com/2007/02/20/merck-admits-it-was-wrong-to-lobby-for-making-hpv-vaccine-mandatory/']
# [83, 'Merck lobbying', '35.2988', '2', 'http://womenshealthnews.wordpress.com/2007/02/21/merck-to-stop-lobbying-for-mandatory-hpv-vaccines/']
# [83, 'Merck lobbying', '78.9267', '5', 'http://geknitics.com/2007/02/merck-stops-lobbying-lawmakers/']
# [83, 'Merck lobbying', '96.5172', '6', 'http://businessethicsblog.com/2007/02/22/merck-halts-vaccine-lobbying/']
# [83, 'Merck lobbying', '127.2939', '10', 'http://www.upjohn.com/merck-spent-11m-lobbying-government-in-3q-forbes/']
# [84, 'benefits of phd', '277.6929', '', '']
# [84, 'does phd help in getting job after mba', '462.1079', '', '']
# [85, 'gun control and gun violence', '57.5243', '', '']
# [85, 'does gun control effect gun violence', '78.6288', '', '']
# [85, 'does gun control to stop gun violence', '186.0937', '', '']
# [85, 'does gun control to stop gun violence', '213.5561', '3', 'http://americandaily.com/index.php/article/3159']
# [86, '403(b) vs IRA', '22.1151', '', '']
# [86, '403 or IRA better', '55.8379', '', '']
# [86, 'employer retirement or personal', '101.3904', '', '']
# [86, 'employer retirement or personal', '118.3748', '', '']
# [86, 'private or personal retirement fund', '128.4003', '', '']
# [86, 'best retirement fund', '147.2253', '', '']
# [87, 'glassblowing history', '15.9401', '', '']
# [87, 'glassblowing craft history', '31.2570', '', '']
# [87, 'glassblowing wiki', '49.1890', '', '']
# [87, 'glassblowing 18th century', '87.1024', '', '']
# [87, 'glassblowing 19th century', '95.6665', '', '']
# [88, 'Pocono Mountains', '18.8375', '', '']
# [88, 'Pocono Mountains', '26.1148', '4', 'http://www.visitpa.com/pocono-mountains']
# [88, 'Pocono Mountain parks', '49.8885', '', '']
# [88, 'Pocono Mountain parks', '66.2561', '5', 'http://www.babymoonguide.com/pocono-mountains-pennsylvania-babymoon.html']
# [88, 'Pocono Mountain things to do', '83.3705', '', '']
# [88, 'Pocono Mountain things to do', '92.5037', '1', 'http://www.chateauresort.com/default.aspx?pg=recreation']
# [88, 'Pocono Mountain things to do', '120.0175', '2', 'http://www.tripcart.com/usa-regions/Eastern-Pennsylvania,Cool-Things-to-Do.aspx']
# [88, 'Pocono Mountain community', '172.7260', '', '']
# [89, 'best vacation spots', '14.6211', '', '']
# [89, 'best vacation spots', '63.0651', '2', 'http://www.minnesota-visitor.com/best-family-vacation-spots.html']
# [89, 'best vacation spots', '76.8042', '4', 'http://www.tropical-island-vacation.net/mexico-vacation-spots.html']
# [90, 'efficiency of hydropower.', '58.2724', '', '']
# [90, 'efficiency of hydropower.', '70.5659', '1', 'http://www.lawofrenewableenergy.com/2011/12/articles/hydropower/hydropower-regulatory-efficiency-act-of-2011-introduced-in-the-house-of-representatives/']
# [90, 'consequences building hydroelectric dams could have on the environment', '100.0303', '', '']
# [90, 'technology behind hydroelectric power', '139.3547', '', '']
# [90, 'technology behind hydroelectric Electricity', '158', '', '']
# [91, 'Eurozone crisis', '14.1862', '', '']
# [91, 'long term effects Eurozone crisis', '38.9802', '', '']
# [91, 'Eurozone crisis wiki', '61.9191', '', '']
# [91, 'Eurozone crisis cause', '81.9553', '', '']
# [91, 'Eurozone crisis history', '116.4284', '', '']
# [92, 'internet phone service', '15.2516', '', '']
# [92, 'internet phone service reviews', '30.9036', '', '']
# [92, 'internet phone service cost', '47.7457', '', '']
# [92, 'google voice review', '87.4337', '', '']
# [92, 'google voice review', '91.9576', '', '']
# [93, 'Martin Bryant', '8.7653', '', '']
# [93, 'Martin Bryant', '22.1779', '3', 'http://www.truthmedia.8k.com/Martin_Bryant.html']
# [93, 'port arthur gunman', '33.2674', '', '']
# [93, 'port arthur gunman', '42.5321', '2', 'http://www.portarthur.org.au']
# [93, 'port arthur homicide', '78.3465', '', '']
# [93, 'port arthur shooting', '87.7217', '', '']
# [93, 'port arthur shooting', '94.7104', '1', 'http://setxhomepage.com/fulltext?nxd_id=183912']
# [94, 'face transplants', '13.5727', '', '']
# [94, 'face transplant wiki', '25.1113', '', '']
# [94, 'face transplant wiki', '39.3981', '2', 'http://health.howstuffworks.com/wellness/cosmetic-treatments/human-face-transplant.htm']
# [94, 'face transplant wiki', '50.8144', '', '']
# [94, 'face transplant wiki', '57.8479', '1', 'http://www.straightfromthedoc.com/50226711/the_dawn_of_face_transplants.php']
# [94, 'face transplant wiki', '83.8090', '5', 'http://www.newyorker.com/reporting/2012/02/13/120213fa_fact_khatchadourian']
# [94, 'face transplant results', '130.6137', '', '']
# [95, 'face transplants', '16.8818', '', '']
# [95, 'face transplants', '23.9833', '1', 'http://www.bbc.co.uk/news/world-us-canada-17534646']
# [95, 'face transplants before and after', '31.8965', '', '']
# [95, 'face transplants affect lives of patients', '71.0914', '', '']
# [96, 'jp morgan data center', '12.2312', '', '']
# [96, 'chase data center', '17.5719', '', '']
# [96, 'chase "data center"', '28.7465', '', '']
# [96, 'jp morgan "data center"', '36.3315', '', '']
# [96, 'jp morgan "data center"', '69.6579', '', '']
# [96, 'chase computer data center', '88.7690', '', '']
# [97, 'how to cook swahili dishes', '21.2132', '', '']
# [97, 'how to cook swahili dishes', '38.8292', '2', 'http://www.simplyadditions.com/Index/About-Simply-Additions.html']
# [97, 'cooking traditional swahili dishes', '55.1264', '', '']
# [97, 'cooking traditional swahili dishes', '69.7550', '1', 'http://www.epicurien.be/food/recipes/main-dishes/tajines/lamb-tajines.asp']
# [97, 'dishes eaten in swahili', '143.7922', '', '']
# [97, 'dishes eaten in swahili', '152.5828', '3', 'http://www.glcom.com/hassan/swahili.html']
# [97, 'dishes eaten in swahili', '164.4990', '', '']
# [98, 'best VOIP provider', '15.2624', '', '']
# [98, 'best VOIP provider', '49.0837', '1', 'http://www.callcentersolution.com']
# [98, 'VOIP features', '56.7110', '', '']
# [98, 'VOIP features', '60.4257', '2', 'http://voip.about.com/od/voipfeatures/a/featuresvoip.htm']
# [98, 'VOIP provider reviews', '93.5536', '', '']
# [98, 'VOIP provider reviews', '120.5830', '1', 'http://www.vonage-forum.com/forums.html']
# [98, 'VOIP provider reviews', '125.1618', '2', 'http://www.whichvoip.com/voip/business-voip-reviews.htm']
# [98, 'VOIP provider reviews', '129.4444', '3', 'http://www.voipreview.org/review.all.aspx']
# [98, 'VOIP free providers', '177.0112', '', '']
# [99, 'scientific glassblowing', '15.4562', '', '']
# [99, 'scientific glassblowing', '17.5220', '1', 'http://www.ilpi.com/glassblowing/']
# [100, 'Best cities to visit without a car', '42.0809', '', '']
# [100, 'Best cities to visit without a car United States', '55.6461', '', '']
# [100, 'Best cities to visit without a car United States', '104.9975', '', '']
# [101, 'water turbines', '9.3190', '', '']
# [101, 'water turbine wiki', '22.5228', '', '']
# [101, 'water turbine types', '58.8619', '', '']
# [101, 'water turbine types', '72.8383', '', '']
# [101, 'how do water turbines work', '89.1080', '', '']
# [101, 'types of water turbine', '108.5281', '', '']
# [101, 'water turbine newton', '127.2395', '', '']
# [102, 'ongoing Eurozone crisis', '16.9264', '', '']
# [103, 'employee evaluation guide', '13.5631', '', '']
# [103, 'employee evaluation guide', '20.7463', '4', 'http://www.accel-team.com/publications/atPDF_04_empEvaluation.html']
# [103, 'employee evaluation guide', '104.9683', '5', 'http://www.cedrsolutions.com/employee-evaluations-guide-and-form']
# [103, 'employee evaluation advice', '112.2414', '', '']
# [103, 'employee evaluation advice', '116.5819', '5', 'http://www.chartcourse.com/captainsbooks.htm']
# [104, 'traditional swahili food', '11.6518', '', '']
# [104, 'swahili food', '22.2683', '', '']
# [104, 'swahili herbs', '40.4098', '', '']
# [104, 'swahili herbs', '45.3372', '', '']
# [104, 'swahili herbs', '52.8636', '7', 'http://www.kamusiproject.org']
# [104, 'swahili cooking', '91.8369', '', '']
# [104, 'swahili cooking', '102.6286', '1', 'http://www.seedsavers.org/Details.aspx?itemNo=M3410']
# [104, 'swahili restaurant', '125.3148', '', '']
# [104, 'cook swahili food', '141.4849', '', '']
# [105, 'know how many SUNY colleges there are', '17.3986', '', '']
# [105, 'list of SUNY colleges', '37.2625', '', '']
# [105, 'SUNY Albany', '74.6308', '', '']
# [105, 'SUNY bioinformatics', '101.5985', '', '']
# [105, 'SUNY athletic scholarships', '128.3506', '', '']
# [105, 'SUNY international students', '154.9735', '', '']
# [105, 'SUNY "international students"', '179.2811', '', '']
# [105, 'SUNY "international students"', '190.7808', '', '']
# [106, 'silicone roof coating', '11.9078', '', '']
# [106, 'silicone roof coating', '14.4972', '1', 'http://www.weatherstarcoatings.com/pages/products/AWSPDS410.html']
# [106, 'silicone roof coating', '28.7493', '2', 'http://www.weatherstarcoatings.com/pages/products/AWSPDS412.html']
# [106, 'silicone roof coating', '38.0402', '3', 'http://www.weatherstarcoatings.com/pages/studies/urethane_system_with_silicone_roof_coatings_study.html']
# [106, 'silicone roof coating', '47.6419', '8', 'http://www.weatherstarcoatings.com/pages/specs/Single-Ply-SiliconeSystem.html']
# [106, 'silicone roof', '56.1257', '', '']
# [106, 'silicone roof', '62.1678', '3', 'http://www.cnrubberparts.com/rubber-roof-flashing/609591.html']
# [107, 'pocono mountains', '12.0817', '', '']
# [107, 'pocono mountains parks', '26.5965', '', '']
# [107, 'pocono mountains parks', '36.8517', '2', 'http://themeparks.about.com/od/indoorwaterparksphotos/ss/GWLpoconos.htm']
# [107, 'pocono mountains state parks', '64.7990', '', '']
# [107, 'pocono mountains state parks', '99.1332', '6', 'http://www.dcnr.state.pa.us/stateparks/parks/tobyhanna.aspx']
# [107, 'pennsylvania state parks', '114.0247', '', '']
# [107, 'pennsylvania state parks pocono mountains', '130.1284', '', '']
# [108, 'Lara Dutta', '9.8292', '', '']
# [108, 'Indian government competitions', '31.3626', '', '']
# [108, 'Indian government pageant', '45.3345', '', '']
# [108, 'lara dutta govern', '72.0949', '', '']
# [108, 'lara dutta policies', '80.6677', '', '']
# [108, 'lara dutta policies', '89.8686', '', '']
# [108, 'lara dutta policies', '102.2061', '3', 'http://www.stylemeindia.com/people-and-parties/moms-aishwarya-lara-dutta-attend-deshmukhs-reception-12839']
# [108, 'lara dutta policies', '128.4974', '2', 'http://www.desivideos.net/2006/10/19/koffee-with-karan-bipasha-basu-and-lara-dutta/']
# [109, 'depression help', '40.2563', '', '']
# [110, 'different developmental milestones in 0-12 months', '19', '', '']
# [110, 'different developmental milestones in 0-12 months', '21', '', '']
# [110, 'different developmental milestones in 0-12 months', '25', '', '']
# [110, 'culture difference in milestones in 0-12 month olds', '54', '', '']
# [110, 'culture difference in milestones in 0-12 month olds', '63', '', '']
# [110, 'culture difference in milestones in 0-12 month olds', '77', '', '']
# [110, 'culture difference in milestones in 0-12 month olds', '105', '', '']
# [111, 'Dulles airport', '585.6553', '', '']
# [112, 'how to run a technology business', '25.7044', '', '']
# [112, 'run a technology business', '80.4656', '', '']
# [112, 'run a technology business', '103.1496', '6', 'http://sbinfocanada.about.com']
# [112, 'start a technology business', '131.4957', '', '']
# [113, 'Kursk sinking russia', '78.9668', '', '']
# [114, 'Eurozone crisis economic effects', '22.2743', '', '']
# [114, 'Eurozone crisis economic effects by country', '61.2908', '', '']
# [114, 'Eurozone crisis by country', '94.7334', '', '']
# [114, 'Eurozone crisis unemployment GDP', '135.0563', '', '']
# [114, 'Eurozone crisis unemployment GDP', '157.4590', '1', 'http://meetmedaily.com/eurozone-crisis-live-gdp-data-could-show-europes-slide-into-recession/']
# [115, 'JP Morgan Chase data centers location investment', '66.8365', '', '']
# [115, 'JP Morgan Chase data centers location investment', '82.8640', '1', 'http://wpcarey.asu.edu/seid/eoc/']
# [115, 'JP Morgan Chase data centers comparison microsoft facebook', '113.3974', '', '']
# [115, 'JP Morgan Chase data centers comparison microsoft facebook data centers', '131.6960', '', '']
# [115, 'JP Morgan Chase data centers comparison microsoft facebook data centers', '145.9042', '', '']
# [115, 'JP Morgan Chase data centers', '153.3347', '', '']
# [116, 'what is the naturalism theory?', '15.2676', '', '']
# [116, 'naturalism', '31.7434', '', '']
# [116, 'does god exist', '47.8964', '', '']
# [116, 'does god exist naturalism', '61.8724', '', '']
# [117, 'Traditional Swahili dishes', '42.4144', '', '']
# [117, 'Swahili dishes', '89.8870', '', '']
# [117, 'Kenyan cuisine', '139.6408', '', '']
# [117, 'Kenyan cuisine', '171.3653', '1', 'http://kenya.costasur.com/en/restaurants.html']
# [117, 'Kenyan Swahili dishes', '221.1492', '', '']
# [117, 'Swahili', '260.1045', '', '']
# [117, 'Swahili', '310.6328', '3', 'http://www.glcom.com/hassan/swahili_history.html']
# [117, 'kenyan cuisine', '335.2793', '', '']
# [118, 'exciting road trips', '11.3756', '', '']
# [118, 'exciting road trips', '22.0044', '3', 'http://collegelife.about.com/od/cocurricularlife/a/roadtripideas.htm']
# [118, 'themed road trips', '45.5188', '', '']
# [118, 'road trip fun', '60.0544', '', '']
# [118, 'road trip fun', '68.7443', '3', 'http://travelwithkids.about.com/od/cartripstips/a/roadtrips101.htm']
# [118, 'road trip fun', '89.0004', '7', 'http://familyfitness.about.com/od/waystoplay/qt/road_trip_games.htm']
# [118, 'road trip games', '123.7220', '', '']
# [118, 'road trip games', '133.2882', '9', 'http://www.roadtripamerica.com']
# [119, 'gun homicides in Australia', '13.4046', '', '']
# [119, 'Port Arthur Massacre guns Australia', '37.0078', '', '']
# [119, 'Port Arthur Massacre guns Australia', '46.8504', '6', 'http://www.russojapanesewar.com/portarthur1894.html']
# [119, 'Martin Bryant  guns Australia', '69.7939', '', '']
# [120, 'phd business degree', '12.6604', '', '']
# [120, 'phd business degree', '15.8313', '2', 'https://www.ecollegefinder.org/online-phd-in-management.aspx']
# [120, 'phd business degree', '36.7553', '6', 'http://business-mba-personal-statement-help.statementsofpurpose.com']
# [120, 'phd business degree', '41.9106', '9', 'https://www.ecollegefinder.org/online-phd-degree-in-marketing-online.aspx']
# [121, 'US and UK health care and social security systems', '83', '', '']
# [121, 'US and UK health care and social security systems', '138', '', '']
# [121, 'US and UK health care and social security systems', '143', '', '']
# [121, 'US and UK health care and social security systems', '146', '', '']
# [121, 'US and UK health care  systems', '152', '', '']
# [122, 'succeed in new venture', '21.9867', '', '']
# [122, 'succeed in new venture', '31.8887', '1', 'http://www.fundingpost.com/book/mag_main.asp']
# [122, 'new venture', '46.3441', '', '']
# [122, 'new venture', '51.3694', '', '']
# [122, 'new company', '56.8908', '', '']
# [122, 'technology entrepreneur', '75.5346', '', '']
# [122, 'technology entrepreneur', '86.8369', '', '']
# [122, 'technology entrepreneur', '90.9721', '', '']
# [122, 'business decisions new venture', '103.0571', '', '']
# [122, 'business decisions new venture', '114.0097', '', '']
# [122, 'business decisions new venture', '117.0001', '', '']
# [122, 'business decisions new venture', '119.5991', '', '']
# [122, 'how to run new venture', '135.5539', '', '']
# [123, 'HOW TO COOK SWAHILI DISH', '20.5013', '', '']
# [124, 'gun crime in Australia', '162.1076', '', '']
# [125, 'developmental milestones for each culture', '25.3593', '', '']
# [125, 'developmental milestones for each culture', '53.9627', '2', 'http://pediatrics.about.com/od/growthanddevelopment/ig/Developmental-Milestones/']
# [125, 'developmental milestones 0-12 months', '78.9576', '', '']
# [125, 'developmental milestones 0-12 months per culture', '97.0576', '', '']
# ...
# [44, 'merrill lynch location headquarters', '10:04:46.995917', '', '']
# [44, 'merrill lynch location headquarters', '10:05:01.001702', '1', 'http://nyjobsource.com/merrill.html']
# [45, 'first partial face transplant', '08:34:16.733079', '', '']
# [45, 'first partial face transplant', '08:34:20.097245', '2', 'http://en.wikipedia.org/wiki/Isabelle_Dinoire']
# [45, 'isabelle dinoire criticisms', '08:38:35.599314', '', '']
# [46, 'AMT', '09:18:40.692657', '', '']
# [46, 'AMT and Tax', '09:19:08.833988', '', '']
# [46, 'AMT and Tax', '09:19:11.295031', '1', 'http://en.wikipedia.org/wiki/Alternative_Minimum_Tax']
# [46, 'AMT and Tax', '09:19:30.774211', '2', 'http://www.fairmark.com/amt/amt101.htm']
# [46, 'AMT and Tax', '09:19:58.503210', '4', 'http://www.fairmark.com/amt/']
# [46, 'AMT and Tax', '09:20:20.112263', '6', 'http://finance.yahoo.com/how-to-guide/taxes/12810']
# [47, 'Irving Berlin birthplace', '08:11:05.345877', '', '']
# [47, 'Irving Berlin birthplace', '08:11:25.110684', '5', 'http://www.newworldencyclopedia.org/entry/Irving_Berlin']
# [47, 'Irving Berlin list of songs', '08:12:25.212521', '', '']
# [47, 'Irving Berlin list of songs', '08:12:37.674011', '6', 'http://www.thelyricarchive.com/artist/9057/Irving-Berlin']
# [47, 'Irving Berlin list of songs', '08:12:59.864765', '8', 'http://www.americanmusicpreservation.com/songwriters.htm']
# [47, 'Irving Berlin complete list of songs', '08:13:40.839306', '', '']
# [47, 'Irving Berlin complete list of songs', '08:13:54.975971', '2', 'http://parlorsongs.com/bios/berlin/iberlin.php']
# [48, 'cunard cruise lines', '15:31:05.106957', '', '']
# [48, 'cunard cruise lines', '15:31:13.879455', '1', 'http://www.cunard.com/']
# [48, 'cunard cruise lines', '15:32:59.156400', '2', 'http://en.wikipedia.org/wiki/Cunard_Line']
# [48, 'carnival uk', '15:33:51.697030', '', '']
# [48, 'carnival uk', '15:33:57.826853', '1', 'http://www.carnivalukgroup.com/']
# [48, 'cunard cruise lines director', '15:34:49.846739', '', '']
# [49, 'harry potter and the goblet of fire', '15:27:16.944433', '', '']
# [49, 'harry potter and the goblet of fire', '15:27:31.490970', '2', 'http://harrypotter.warnerbros.co.uk/']
# [49, 'harry potter and the goblet of fire', '15:29:29.964322', '3', 'http://en.wikipedia.org/wiki/Harry_Potter_and_the_Goblet_of_Fire']
# [49, 'harry potter and the goblet of fire', '15:31:14.849503', '3', 'http://en.wikipedia.org/wiki/Harry_Potter_and_the_Goblet_of_Fire']
# [49, 'harry potter and the goblet of fire', '15:32:11.817998', '7', 'http://harrypotter.wikia.com/wiki/Harry_Potter_and_the_Goblet_of_Fire']
# [49, 'harry potter and the goblet of fire', '15:34:56.114988', '5', 'http://www.goodreads.com/book/show/6.Harry_Potter_and_the_Goblet_of_Fire']
# [49, 'harry potter and the goblet of fire', '15:36:30.523458', '4', 'http://www.moviefone.com/movie/harry-potter-and-the-goblet-of-fire/19563/main']
# [49, 'harry potter and the goblet of fire book', '15:37:32.458193', '', '']
# [49, 'harry potter and the goblet of fire book', '15:38:02.086297', '3', 'http://www.cuttingedge.org/news/n1430.cfm']
# [49, 'harry potter and the goblet of fire book translations', '15:39:19.613259', '', '']
# [49, 'harry potter and the goblet of fire book translations', '15:39:40.230835', '5', 'http://encyclopedia.wizards.pro/index.php/Harry_Potter_and_the_Goblet_of_Fire']
# [50, '"jasper fforde" chronology', '03:27:13.343229', '', '']
# [50, '"jasper fforde" chronology', '03:27:27.192073', '1', 'http://www.jasperfforde.com/index4.html']
# [50, '"jasper fforde" questions answers contents', '03:29:12.670605', '', '']
# [51, 'founder Guinness Brewery', '16:59:31.494867', '', '']
# [51, 'founder Guinness Brewery', '16:59:42.262595', '1', 'http://en.wikipedia.org/wiki/Arthur_Guinness']
# [51, 'Guinnes Brewmaster 2006', '17:01:10.091946', '', '']
# [51, 'Guinness Brewmaster 2006', '17:01:38.422634', '', '']
# [51, 'Guinness 2006', '17:02:11.499019', '', '']
# [52, 'Guinness brewery established', '09:36:16.786039', '', '']
# [52, 'Guinness brewmaster 2006', '09:37:05.271521', '', '']
# [52, '"Guinness brewmaster"  2006', '09:38:34.191562', '', '']
# [52, '"Guinness brewmaster"  2006', '09:38:45.976488', '1', 'http://www.whitebeertravels.co.uk/dublin.html']
# [52, 'Guinness sales per day Ireland', '09:40:14.379920', '', '']
# [52, 'Guinness sale of pints per day Ireland', '09:40:58.739494', '', '']
# [52, 'percent of alcohol by volume in Guinness', '09:41:42.698870', '', '']
# [53, 'hybrid vehicle sales usa', '08:27:55.664537', '', '']
# [53, 'hybrid vehicle sales usa', '08:28:03.339446', '1', 'http://en.wikipedia.org/wiki/Hybrid_electric_vehicle']
# [53, 'first ever hybrid car', '08:29:09.497045', '', '']
# [53, 'first ever hybrid car', '08:29:14.855378', '2', 'http://www.hybridcars.com/history/history-of-hybrid-vehicles.html']
# [53, 'percentage sales of hybrid vehicles in 2004 usa', '08:30:21.963645', '', '']
# [53, 'percentage sales of hybrid vehicles in 2004 usa', '08:30:29.323713', '2', 'http://www.greencarcongress.com/2005/09/us_hybrid_sales.html']
# [54, 'American girl dolls', '15:45:00.348206', '', '']
# [54, 'American girl dolls', '15:45:25.618387', '8', 'http://collectdolls.about.com/od/dollprofiles/p/americangirls.htm']
# [54, 'New York American Girl dolls price', '15:46:48.941529', '', '']
# [54, 'New York American Girl dolls price', '15:46:55.001353', '1', 'http://www.americangirl.com/stores/location_ny.php']
# [54, 'New York American Girl dolls cost', '15:47:46.773419', '', '']
# [54, 'American Girl dolls cost $', '15:48:13.597863', '', '']
# [54, 'American Girl dolls cost $', '15:48:20.922072', '2', 'http://pages.ebay.com/buy/guides/american-girl-dolls-buying-guide/']
# [54, 'American Girl doll retail price', '15:49:04.849042', '', '']
# [54, 'American Girl doll wiki', '15:49:27.832463', '', '']
# [54, 'American Girl doll wiki', '15:49:34.522986', '2', 'http://www.fanhistory.com/wiki/American_Girl']
# [54, 'American Girl doll wiki', '15:50:09.968106', '3', 'http://en.wikipedia.org/wiki/Doll']
# [55, 'chanel company', '14:39:17.029837', '', '']
# [55, 'chanel company', '14:39:33.189574', '2', 'http://womenshistory.about.com/od/chanelcoco/a/coco_chanel.htm']
# [55, 'chanel company', '14:40:27.234319', '1', 'http://en.wikipedia.org/wiki/Chanel']
# [55, 'chanel museum exhibition clothing', '14:42:31.430884', '', '']
# [55, 'chanel museum exhibition clothing', '14:42:37.759588', '2', 'http://www.thecityreview.com/chanel4.html']
# [55, 'chanel museum exhibition clothing', '14:43:27.026747', '3', 'http://partners.nytimes.com/library/style/052300chanel-notebook.html']
# [55, 'chanel museum exhibition clothing', '14:43:51.378482', '7', 'http://golondon.about.com/od/temporaryexhibitions/fr/littleblackdres.htm']
# [55, 'chanel museum exhibition clothing', '14:44:20.418944', '10', 'http://blogs.fashionclub.com/my_weblog/fidm_museum_galleries/']
# [55, 'chanel president', '14:45:37.126320', '', '']
# [55, 'chanel president', '14:45:59.702815', '6', 'http://www.zimbio.com/Chanel']
# [55, 'chanel clothes award ceremonies women', '14:47:00.440872', '', '']
# [55, 'chanel clothes award ceremonies women', '14:47:14.761023', '4', 'http://chicstories.com/tag/globe/']
# [55, 'chanel clothes award ceremonies women', '14:47:51.258625', '7', 'http://www.fashion-era.com/perfume_history.htm']
# [55, 'chanel clothes award ceremonies women', '14:48:30.290956', '10', 'http://stylescenes.latimes.com/fashion/chanel/']
# [55, 'chanel top fragrance', '14:49:33.127425', '', '']
# [56, '2005 presidential election in Egypt', '20:55:16.756673', '', '']
# [56, '2005 presidential election in Egypt', '20:55:46.016813', '1', 'http://en.wikipedia.org/wiki/Egyptian_presidential_election,_2005']
# [56, '2005 presidential election in Egypt', '20:57:11.307784', '2', 'http://psephos.adam-carr.net/countries/e/egypt/']
# [56, '2005 presidential election in Egypt', '20:57:31.524579', '5', 'http://www.eohr.org/report/2005/re0910.shtml']
# [56, '2005 presidential election in Egypt, forgery', '20:58:11.911339', '', '']
# [56, '2005 presidential election in Egypt, forgery', '20:58:27.618566', '2', 'http://www.jewishvirtuallibrary.org/jsource/biography/Mubarak.html']
# [56, '2005 presidential election in Egypt, forgery', '20:58:40.462841', '5', 'http://www.answers.com/topic/egypt']
# [57, '"2005 world snooker championships"', '15:18:15.550565', '', '']
# [57, '"2005 world snooker championship"', '15:19:04.938659', '', '']
# [57, '"2005 world snooker championship"', '15:19:24.045019', '1', 'http://en.wikipedia.org/wiki/Shaun_Murphy_(snooker_player)']
# [57, '"2005 world snooker championship"', '15:19:55.381110', '3', 'http://litrvalo.somee.com/articles/world-snooker.htm']
# [57, '2005 "world snooker" championship', '15:20:43.315080', '', '']
# [57, '2005 "world snooker" championship', '15:21:09.279948', '1', 'http://en.wikipedia.org/wiki/World_Snooker_Championship']
# [57, '2005 "world snooker" championship', '15:21:57.849403', '32', 'http://www.boxcheats.com/world_snooker_championship_2005.shtml']
# [57, '"world snooker" "tournaments annually"', '15:23:05.043639', '', '']
# [57, '"world snooker" tournaments', '15:23:28.584630', '', '']
# [57, '"world snooker" tournaments', '15:23:32.917449', '1', 'http://en.wikipedia.org/wiki/List_of_snooker_tournaments']
# [57, '"world snooker" tournaments', '15:23:51.038434', '2', 'http://www.hobbystop.net/Snooker/A_Brief_Tour_Of_Major_Snooker_Tournaments.html']
# [57, '"world snooker" "reigning superstar"', '15:24:58.611379', '', '']
# [58, 'marsupials ecology behaviur', '13:11:45.451991', '', '']
# [58, 'marsupials ecology behaviur', '13:11:59.807582', '1', 'http://www.life.umd.edu/classroom/bsci338m/Lectures/Monotremes.html']
# [58, 'marsupials ecology behaviur', '13:12:13.919495', '3', 'http://en.wikipedia.org/wiki/Marsupial']
# [58, 'marsupials cartoon', '13:13:13.954359', '', '']
# [59, 'where do marsupials keep their young', '08:59:29.871682', '', '']
# [59, 'where do marsupials keep their young', '08:59:39.317890', '1', 'http://science.jrank.org/pages/4151/Marsupials.html']
# [59, 'non-extinct marsupials', '09:00:19.687486', '', '']
# [59, '"non-extinct" marsupials', '09:01:14.972617', '', '']
# [59, 'non-extinct marsupials', '09:02:30.276520', '', '']
# [59, 'where do marsupials keep their young', '09:02:37.085128', '', '']
# [59, 'marsupials', '09:02:44.156458', '', '']
# [59, 'marsupials', '09:02:44.569322', '1', 'http://en.wikipedia.org/wiki/Marsupial']
# [59, 'largest meat eating marsupial', '09:03:35.257783', '', '']
# [59, 'largest meat eating marsupial', '09:03:45.531506', '2', 'http://www.zoomwhales.com/subjects/mammals/marsupial/Tazdevilprintout.shtml']
# [59, 'marsupial outside australia', '09:04:24.898710', '', '']
# [59, 'marsupial outside australia', '09:04:57.378269', '5', 'http://www.backyardnature.net/opossums.htm']
# [59, 'marsupial manure', '09:05:54.656400', '', '']
# [59, '"marsupial manure"', '09:06:17.453802', '', '']
# [59, '"marsupial manure"', '09:06:28.664112', '3', 'http://snltranscripts.jt.org/04/04mupdate.phtml']
# [60, 'alan greenspan', '16:26:58.015064', '', '']
# [60, 'alan greenspan', '16:27:03.473204', '1', 'http://en.wikipedia.org/wiki/Alan_Greenspan']
# [60, 'alan greenspan', '16:27:44.804384', '1', 'http://en.wikipedia.org/wiki/Alan_Greenspan']
# [61, 'History of FISA', '19:00:21.271028', '', '']
# [61, 'FISA wiretap applications', '19:08:08.543623', '', '']
# [62, 'FISA', '10:22:18.354536', '', '']
# [62, 'FISA', '10:22:24.741170', '1', 'http://en.wikipedia.org/wiki/Foreign_Intelligence_Surveillance_Act']
# [62, 'judges on fisa court', '10:23:45.954158', '', '']
# [62, '1990 FISA wiretap applications', '10:24:23.987867', '', '']
# [62, '1990 FISA wiretap applications', '10:24:29.616850', '1', 'http://www.cdt.org/wiretap/wiretap_overview.html']
# [62, 'judges FISA court', '10:25:52.080185', '', '']
# [63, 'australia wine export data', '10:07:41.923511', '', '']
# [63, 'australia wine export data', '10:08:30.766274', '3', 'http://www.australianexportwine.com.au/wine_links.asp']
# [63, 'australia wine export to United States', '10:09:47.899968', '', '']
# [63, 'australia wine export to United States', '10:09:58.010863', '5', 'http://www.titlepublish.com/food-and-drink/wine-and-spirits/australia-as-a-wine-making-region.html']
# [63, 'australia wine export to United States', '10:10:11.485929', '9', 'http://www.winetitles.com.au/awol/overview/exports.asp']
# [64, 'Australian wine Yellowtail', '17:24:39.470539', '', '']
# [64, 'Australian wine Yellowtail', '17:24:44.089099', '3', 'http://en.wikipedia.org/wiki/Yellow_Tail_(wine)']
# [64, 'Australian female winemakers', '17:25:14.056127', '', '']
# [64, 'Australia female wine makers', '17:25:51.197408', '', '']
# [64, 'Australia female wine makers', '17:25:56.761452', '1', 'http://www.thewinedoctor.com/tastingsformal/femalewinemakers.shtml']
# [65, 'Australian wine award 2011', '11:22:14.479876', '', '']
# [65, 'Australian wine award 2011', '11:22:32.488951', '3', 'http://en.wikipedia.org/wiki/Australian_wine']
# [65, 'Shiraz predominant grape Australia', '11:24:59.823882', '', '']
# [65, 'Australia wine export to US', '11:25:58.157239', '', '']
# [65, 'Yellowtail wine Australia', '11:27:17.909873', '', '']
# [65, 'Yellowtail wine Australia', '11:27:22.632140', '1', 'http://www.yellowtailwine.com/']
# [65, 'Yellowtail wine Australia', '11:29:29.545229', '2', 'http://en.wikipedia.org/wiki/Yellow_Tail_(wine)']
# [65, 'female winemakers Australia', '11:30:17.576203', '', '']
# [66, 'joseph steffen', '17:27:12.484465', '', '']
# [66, '"joseph steffen"', '17:27:29.271969', '', '']
# [67, 'jack nicholson imdb', '10:51:15.932510', '', '']
# [67, 'jack nicholson imdb', '10:51:40.974832', '1', 'http://www.imdb.com/name/nm0000197/']
# [67, 'jack nicholson co stars', '10:52:39.833814', '', '']
# [67, 'jack nicholson  and his co stars', '10:53:13.934386', '', '']
# [67, 'jack nicholson  and his co stars', '10:53:21.423320', '2', 'http://www.destinationhollywood.com/celebrities/jacknicholson/dhsuggests_content.shtml']
# [67, 'co stars of jack nicholson', '10:54:44.038412', '', '']
# [67, 'co stars of jack nicholson', '10:54:50.258934', '2', 'http://www.popstarsplus.com/actors_jacknicholson.htm']
# [68, '"space sounds like" astronauts', '17:14:07.431380', '', '']
# [68, '"space sounds like" astronauts', '17:14:27.946229', '2', 'http://coe.berkeley.edu/news-center/publications/forefront/archive/forefront-fall-2007/features/an-intentional-life-software-engineer-charles-simonyi-b-s-201972-eng-math-scores-success-with-space-sojourn']
# [69, 'frequency hematology report', '20:21:46.272409', '', '']
# [69, 'frequency hematology report body chemistry', '20:22:12.307366', '', '']
# [70, '"pest control" how to', '18:07:46.040660', '', '']
# [70, '"pest control" how to', '18:08:02.782513', '1', 'http://www.doyourownpestcontrol.com/silverfish.htm']
# [70, '"pest control" courses', '18:09:31.107991', '', '']
# [70, '"pest control" courses', '18:09:46.591609', '2', 'http://www.rezahealthtec.com/training/pest_control_courses.aspx']
# [70, '"pest control" courses', '18:10:34.519701', '5', 'http://www.wdopestboard.ca.gov/']
# [71, 'how accurate are home pregnancy tests', '19:38:10.051101', '', '']
# [71, 'how accurate are home pregnancy tests', '19:38:41.004234', '7', 'http://www.whattoexpect.com/preconception/fertility/putting-home-pregnancy-tests-to-the-test.aspx']
# [72, 'history of crossword puzzle', '16:00:35.403748', '', '']
# [72, 'history of crossword puzzle', '16:00:53.188982', '1', 'http://crosswordtournament.com/more/wynne.html']
# [72, 'history of crossword puzzle', '16:01:53.873005', '3', 'http://inventors.about.com/od/cstartinventions/a/crossword.htm']
# [72, 'history of crossword puzzle', '16:02:27.210030', '2', 'http://www.flocabulary.com/history/historypuzzles']
# [72, 'history of crossword puzzle', '16:02:57.236768', '7', 'http://www.edinformatics.com/inventions_inventors/crossword_puzzle.htm']
# [73, '"hospital anxiety and depression scale" scales references', '17:07:57.625726', '', '']
# [73, '"hospital anxiety and depression scale" scales references', '17:08:04.941707', '1', 'http://idacc.healthbase.info/questionnaires.html']
# [74, 'introduction trust fund', '08:31:09.818944', '', '']
# [74, 'wiki trust fund', '08:32:06.057362', '', '']

# %%
len(sessions)
# Out:
# 1557

# %%
import pickle
pickle.dump( sessions, open( "TRECS.p", "wb" ) )
