# %% [markdown]
# The code in this notebook combines all the extracted feature sets to allow for experimentation.

# %% [markdown]
# # Load Libraries

# %%
import pickle
import pandas as pd

# %% [markdown]
# # Load Data Sets And Preprocess
#
# The following block of code loads up the two data sets and starts steps towards preprocessing them for our experiments.

# %%
SWC = pickle.load( open( "../Data/DataSets/SWC/SWC.p", "rb" ) )
SQS = pickle.load( open( "../Data/DataSets/SQS/SQS.p", "rb" ) )

SWC = SWC[['sID', 'query', 'type', 'class']]
SQS = SQS[['sID', 'query', 'class']]

# %%
SQS
# Out:
#        sID                                              query  class
# 0    39899                collagen vascular disease lifestyle      0
# 1    39900                    france world cup 1998 reactions      0
# 2    39901                    dooney bourke look alike purses      0
# 3    39902                                        VOIP phones      0
# 4    39903                              Travel to the poconos      0
# ..     ...                                                ...    ...
# 296  41399  Who plays the bad guy in Star Wars the Horde a...      1
# 297  41400             What is a fox's favorite kind of food?      1
# 298  41401             Show me the movie called "The Martian"      1
# 299  41402            What is the biggest rock found on Mars?      1
# 300  41403                    What is the top game this week?      1
#
# [1505 rows x 3 columns]

# %% [markdown]
# # Load Extracted Features
#
# In the following block of code we load all feature sets before merging all the text based features into one dataframe before joining all feature sets together.

# %%
searchFeatSWC = pickle.load( open( "Pickles/SearchFeatSWC.p", "rb" ) )
searchFeatSQS = pickle.load( open( "Pickles/SearchFeatSQS.p", "rb" ) )

vocabFeat = pickle.load( open( "Pickles/VocabFeat.p", "rb" ) )
lexFeat = pickle.load( open( "Pickles/LexFeat.p", "rb" ) )
synFeat = pickle.load( open( "Pickles/SynFeat.p", "rb" ) )
sPFeat = pickle.load( open( "Pickles/SPFeat.p", "rb" ) )

textBasedFeat = sPFeat.merge(vocabFeat)
textBasedFeat = textBasedFeat.merge(lexFeat)
textBasedFeat = textBasedFeat.merge(synFeat)

SWCAll = SWC.merge(textBasedFeat, how='inner', on='query')
SWCAll = SWCAll[SWCAll['type'] == 'Q'].groupby('sID').mean()
SWCAll = SWCAll.join(searchFeatSWC)

SQSAll = SQS.merge(textBasedFeat, how='inner', on='query')
SQSAll = SQSAll.set_index('sID')
SQSAll = SQSAll.merge(searchFeatSQS)
SQSAll = SQSAll.drop(columns = ['query'])

# %%
SQSQ = SQSAll['query'].tolist()

# %%
SQSAll = SQS.merge(textBasedFeat, how='inner', on='query')
SQSAll = SQSAll.set_index('sID')
SQSAll = SQSAll.merge(searchFeatSQS)
# SQSAll = SQSAll.drop(columns = ['query'])
SQSAll[SQSAll['query'].isin(SQSQ)]
# Out:
#                                                   query  class  \
# 0                   collagen vascular disease lifestyle      0
# 1                       france world cup 1998 reactions      0
# 2                       dooney bourke look alike purses      0
# 3                                           VOIP phones      0
# 4                                 Travel to the poconos      0
# ...                                                 ...    ...
# 1522  Who plays the bad guy in Star Wars the Horde a...      1
# 1523             What is a fox's favorite kind of food?      1
# 1524             Show me the movie called "The Martian"      1
# 1525            What is the biggest rock found on Mars?      1
# 1526                    What is the top game this week?      1
#
#       numSpellingErrors  offByOne  kidsError  punct  casing  coreVocab  \
# 0                     0         0          0      0       0   0.000000
# 1                     0         0          0      0       0   0.400000
# 2                     2         2          0      0       0   0.400000
# 3                     1         1          0      0       1   0.500000
# 4                     0         0          0      0       1   0.500000
# ...                 ...       ...        ...    ...     ...        ...
# 1522                  1         1          0      1       1   0.545455
# 1523                  1         1          0      1       1   0.750000
# 1524                  0         0          0      0       1   0.428571
# 1525                  0         0          0      1       1   0.750000
# 1526                  0         0          0      1       1   0.857143
#
#       nonCoreVocab  minAoA  ...  queryDistance  timeQueries  uniqueQueries  \
# 0         1.000000    7.55  ...             -1           -1              1
# 1         0.600000    0.00  ...             -1           -1              1
# 2         0.600000    0.00  ...             -1           -1              1
# 3         0.500000    0.00  ...             -1           -1              1
# 4         0.500000    0.00  ...             -1           -1              1
# ...            ...     ...  ...            ...          ...            ...
# 1522      0.454545    0.00  ...             -1           -1              1
# 1523      0.250000    0.00  ...             -1           -1              1
# 1524      0.571429    0.00  ...             -1           -1              1
# 1525      0.250000    0.00  ...             -1           -1              1
# 1526      0.142857    0.00  ...             -1           -1              1
#
#       allSameQueries  repeatQueries  uniqueClicks  allSameClicks  \
# 0                  0             -1            -1             -1
# 1                  0             -1            -1             -1
# 2                  0             -1            -1             -1
# 3                  0             -1            -1             -1
# 4                  0             -1            -1             -1
# ...              ...            ...           ...            ...
# 1522               0             -1            -1             -1
# 1523               0             -1            -1             -1
# 1524               0             -1            -1             -1
# 1525               0             -1            -1             -1
# 1526               0             -1            -1             -1
#
#       repeatClicks  timeClicks  clickDistance
# 0               -1          -1             -1
# 1               -1          -1             -1
# 2               -1          -1             -1
# 3               -1          -1             -1
# 4               -1          -1             -1
# ...            ...         ...            ...
# 1522            -1          -1             -1
# 1523            -1          -1             -1
# 1524            -1          -1             -1
# 1525            -1          -1             -1
# 1526            -1          -1             -1
#
# [1527 rows x 138 columns]

# %%
searchFeatSQS
# Out:
#                                                    query  class  numQueries  \
# sID
# 39899                collagen vascular disease lifestyle      0           1
# 39900                    france world cup 1998 reactions      0           1
# 39901                    dooney bourke look alike purses      0           1
# 39902                                        VOIP phones      0           1
# 39903                              Travel to the poconos      0           1
# ...                                                  ...    ...         ...
# 41399  Who plays the bad guy in Star Wars the Horde a...      1           1
# 41400             What is a fox's favorite kind of food?      1           1
# 41401             Show me the movie called "The Martian"      1           1
# 41402            What is the biggest rock found on Mars?      1           1
# 41403                    What is the top game this week?      1           1
#
#        numClicks  numClicksPerQuery  meanClickPosition  queryDistance  \
# sID
# 39899         -1                 -1                 -1             -1
# 39900         -1                 -1                 -1             -1
# 39901         -1                 -1                 -1             -1
# 39902         -1                 -1                 -1             -1
# 39903         -1                 -1                 -1             -1
# ...          ...                ...                ...            ...
# 41399         -1                 -1                 -1             -1
# 41400         -1                 -1                 -1             -1
# 41401         -1                 -1                 -1             -1
# 41402         -1                 -1                 -1             -1
# 41403         -1                 -1                 -1             -1
#
#        timeQueries  uniqueQueries  allSameQueries  repeatQueries  \
# sID
# 39899           -1              1               0             -1
# 39900           -1              1               0             -1
# 39901           -1              1               0             -1
# 39902           -1              1               0             -1
# 39903           -1              1               0             -1
# ...            ...            ...             ...            ...
# 41399           -1              1               0             -1
# 41400           -1              1               0             -1
# 41401           -1              1               0             -1
# 41402           -1              1               0             -1
# 41403           -1              1               0             -1
#
#        uniqueClicks  allSameClicks  repeatClicks  timeClicks  clickDistance
# sID
# 39899            -1             -1            -1          -1             -1
# 39900            -1             -1            -1          -1             -1
# 39901            -1             -1            -1          -1             -1
# 39902            -1             -1            -1          -1             -1
# 39903            -1             -1            -1          -1             -1
# ...             ...            ...           ...         ...            ...
# 41399            -1             -1            -1          -1             -1
# 41400            -1             -1            -1          -1             -1
# 41401            -1             -1            -1          -1             -1
# 41402            -1             -1            -1          -1             -1
# 41403            -1             -1            -1          -1             -1
#
# [1505 rows x 16 columns]

# %% [markdown]
# # Return Aggregated Extracted Features
#
# The following block of code returns the extracted features aggregated with their respective data sets.

# %%
pickle.dump(SWCAll, open( "DataSets/SWCFeatures/SWCFeat.p", "wb" ) )
pickle.dump(SQSAll, open( "DataSets/SQSFeatures/SQSFeat.p", "wb" ) )
