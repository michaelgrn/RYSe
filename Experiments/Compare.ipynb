# %% [markdown]
# # Comparison

# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from tqdm import tqdm


rng = np.random.RandomState(20210414)

# %%
SWCAll =  pickle.load( open( "../FeatureExtraction/DataSets/SWCFeatures/SWCFeat.p", "rb" ) )
searchFeatSWC = pickle.load( open( "../FeatureExtraction/Pickles/SearchFeatSWC.p", "rb" ) )

# %%
searchFeatSWC[searchFeatSWC['sID'] == 7]
# Out:
#     sID             query timestamp click  \
# 42    7  prom hair styles         0
# 43    7  prom hair styles        91
# 44    7  prom hair styles        91     1
# 45    7  prom hair styles        91     3
# 46    7  prom hair styles        91     4
# 47    7  prom hair styles       164
# 48    7  prom hair styles       164    57
# 49    7  prom hair styles       164    59
# 50    7  prom hair styles       164    61
# 51    7  prom hair styles       164    63
# 52    7  prom hair styles       164    64
# 53    7  prom hair styles       164    65
#
#                                     website type  order  class  queryDistance  \
# 42                                             Q      0      1              0
# 43                                             Q      1      1              0
# 44   http://hairstyles.free-beauty-tips.com    C      2      1             -1
# 45           http://www.prom-hairstyles.org    C      3      1             -1
# ...

# %%
FlatALL = pickle.load( open( "../../thesis/Classification/FlatALL.p", "rb" ) )
FlatALLCols = FlatALL.columns.tolist()

# %%
for column in SWCAll.columns.tolist():
    if column in FlatALLCols:
        if(SWCAll[column].equals(FlatALL[column]) == False):
            print(column, False)
# Out:
# top50bi False
# top50biNot False
# top50biNA False
# top50biavgNA False
# top50biNotNA False
# tfidf False
# tfidfNA False
# repeatClicks False
# clickDistance False
# meanClickPosition False
# numQueries False
# timeClicks False
# queryDistance False
# timeQueries False
# repeatQueries False

# %%
numR = (FlatALL['inter'] == SWCAll['inter'])

# %%
FlatALL['inter'] == SWCAll['inter']
# Out:
# sID
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 39895    True
# 39896    True
# 39897    True
# 39898    True
# 39899    True
# Name: inter, Length: 39370, dtype: bool

# %%
numR[numR == False]
# Out:
# Series([], Name: inter, dtype: bool)

# %%
FlatALL.iloc[56]['inter']
# Out:
# 1.0

# %%
SWCAll.iloc[56]['inter']
# Out:
# 1.0

# %%
searchFeatSWC[searchFeatSWC['sID'] == 56]
# Out:
#      sID       query timestamp click               website type  order  class  \
# 337   56  what is 4h         0                                Q      0      1
# 338   56  what is 4h         0     3  http://www.4husa.org    C      1      1
# 339   56  what is 4h         0    10    http://www.uri.edu    C      2      1
#
#      queryDistance  timeQueries  ...  allSameQueries  repeatClicks  \
# 337              0          0.0  ...              -1             0
# 338             -1         -1.0  ...              -1             0
# 339             -1         -1.0  ...              -1             0
#
#      uniqueClicks  allSameClicks  timeClicks  clickDistance  numQueries  \
# 337             2              0    0.000000             -1           1
# 338             2              0   34.000000             17           1
# 339             2              0   69.333333             16           1
#
#      numClicks  meanClickPosition  numClicksPerQuery
# ...

# %%
SWCAll['stopCount'].head(10)
# Out:
# sID
# 0    1.000000
# 1    0.000000
# 2    0.333333
# 3    0.000000
# 4    1.000000
# 5    0.000000
# 6    0.500000
# 7    0.000000
# 8    0.000000
# 9    0.000000
# Name: stopCount, dtype: float64

# %%
FlatALL['stopCount'].head(10)
# Out:
# sID
# 0    1.000000
# 1    0.000000
# 2    0.333333
# 3    0.000000
# 4    1.000000
# 5    0.000000
# 6    0.500000
# 7    0.000000
# 8    0.000000
# 9    0.000000
# Name: stopCount, dtype: float64

# %%
numQ = (FlatALL['numQ'] == SWCAll['numQ'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'numQ'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-060e50504217> in <module>
# ...

# %%
numQ[numQ == False]

# %%
FlatALL['stopCount']

# %%
SWCAll['stopCount']
